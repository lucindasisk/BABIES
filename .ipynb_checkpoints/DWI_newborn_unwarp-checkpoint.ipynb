# %%
import pandas as pd
import os
import glob
from shutil import copyfile
import nipype.pipeline.engine as pe
from nipype.interfaces import fsl
# Out:
# /usr/local/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
#Set filepaths and variables
fp = '/Volumes/iang/active/BABIES/BABIES_Longitudinal/BABIES_Longitudinal-T2'
home = '/Volumes/iang/active/BABIES/BABIES_diffusion/subjsDir/'
destfp = '/Volumes/iang/active/BABIES/BABIES_diffusion/subjsDir/Newborn'
params = home + 'acq_params.txt'
index = home + 'index.txt'
index104 = home + 'index104.txt'
index105 = home + 'index105.txt'
index1 = pd.read_csv(home + 'index105.txt', sep = " ", header = None)
workflow_dir = '/Volumes/iang/active/BABIES/BABIES_diffusion/workflows'
print(len(index1))

#Extract subject list and create new list of subjects to be processed
sub = pd.Series(glob.glob(str(fp) + '/*L-T2')).sort_values().str.lstrip('/Volumes/iang/active/BABIES/BABIES_Longitudinal/BABIES_Longitudinal-T')
subs = sub.str[2:12]
ready_to_run = []
# Out:
# 104

# %%
#Run through subject list and determine
for sub in subs:
    if os.path.exists(fp + '/' + sub + '/anat/dwi/recon/DTI_pe0_ms103.nii.gz'):
        print('Data found for {}'.format(sub))
        if os.path.exists(destfp + '/' + sub + '/DTI_pe0_eddy.nii.gz'):
                print('Unwarping and eddy correction already completed for {}'.format(sub))
        else:
            print('Checking directories for {}'.format(sub))
            if os.path.exists(destfp + '/' +sub):
                print('Subject folder created for {}'.format(sub))
                if os.path.exists(destfp + '/' +sub+'/raw'):
                    print('Raw folder created for {}'.format(sub))
                    if os.path.exists(destfp + '/' +sub+'/raw/DTI_pe0_ms103.nii.gz'):
                        print('pe0 copied over')
                        if os.path.exists(destfp + '/' +sub+'/raw/DTI_pe1.nii.gz'):
                            print('pe1 also copied over')
                            ready_to_run.append(sub)
                        else:
                            copyfile(fp + '/' + sub + '/anat/dwi/recon/DTI_pe0_ms103.nii.gz', destfp + '/' + sub + '/raw/DTI_pe0_ms103.nii.gz')
                        copyfile(fp + '/' + sub + '/anat/dwi/recon/DTI_pe0_ms103.bval', 
                                 destfp + '/' + sub + '/raw/DTI_pe0_ms103.bval')
                        copyfile(fp + '/' + sub + '/anat/dwi/recon/DTI_pe0_ms103.bvec', 
                                 destfp + '/' + sub + '/raw/DTI_pe0_ms103.bvec')
                        copyfile(fp + '/' + sub + '/anat/dwi/recon/DTI_pe1.bval', 
                                 destfp + '/' + sub + '/raw/DTI_pe1.bval')
                        copyfile(fp + '/' + sub + '/anat/dwi/recon/DTI_pe1.bvec', 
                                 destfp + '/' + sub + '/raw/DTI_pe1.bvec')
                    else:
                        copyfile(fp + '/' + sub + '/anat/dwi/recon/DTI_pe0_ms103.nii.gz', destfp + '/' + sub + '/raw/DTI_pe0_ms103.nii.gz')
                        copyfile(fp + '/' + sub + '/anat/dwi/recon/DTI_pe0_ms103.bval', 
                                 destfp + '/' + sub + '/raw/DTI_pe0_ms103.bval')
                        copyfile(fp + '/' + sub + '/anat/dwi/recon/DTI_pe0_ms103.bvec', 
                                 destfp + '/' + sub + '/raw/DTI_pe0_ms103.bvec')
                        copyfile(fp + '/' + sub + '/anat/dwi/recon/DTI_pe1.nii.gz', destfp + '/' + sub + '/raw/DTI_pe1.nii.gz')
                        copyfile(fp + '/' + sub + '/anat/dwi/recon/DTI_pe1.bval', 
                                 destfp + '/' + sub + '/raw/DTI_pe1.bval')
                        copyfile(fp + '/' + sub + '/anat/dwi/recon/DTI_pe1.bvec', 
                                 destfp + '/' + sub + '/raw/DTI_pe1.bvec')
                else:
                    os.mkdir(destfp + '/' +sub+'/raw')
                    copyfile(fp + '/' + sub + '/anat/dwi/recon/DTI_pe0_ms103.nii.gz', destfp + '/' + sub + '/raw/DTI_pe0_ms103.nii.gz')
                    copyfile(fp + '/' + sub + '/anat/dwi/recon/DTI_pe0_ms103.bval', 
                             destfp + '/' + sub + '/raw/DTI_pe0_ms103.bval')
                    copyfile(fp + '/' + sub + '/anat/dwi/recon/DTI_pe0_ms103.bvec', 
                             destfp + '/' + sub + '/raw/DTI_pe0_ms103.bvec')
                    copyfile(fp + '/' + sub + '/anat/dwi/recon/DTI_pe1.nii.gz', destfp + '/' + sub + '/raw/DTI_pe1.nii.gz')
                    copyfile(fp + '/' + sub + '/anat/dwi/recon/DTI_pe1.bval', 
                             destfp + '/' + sub + '/raw/DTI_pe1.bval')
                    copyfile(fp + '/' + sub + '/anat/dwi/recon/DTI_pe1.bvec', 
                             destfp + '/' + sub + '/raw/DTI_pe1.bvec')
            else:
                os.mkdir(destfp + '/' +sub)
                os.mkdir(destfp + '/' +sub+'/raw')
                copyfile(fp + '/' + sub + '/anat/dwi/recon/DTI_pe0_ms103.nii.gz', destfp + '/' + sub + '/raw/DTI_pe0_ms103.nii.gz')
                copyfile(fp + '/' + sub + '/anat/dwi/recon/DTI_pe0_ms103.bval', 
                         destfp + '/' + sub + '/raw/DTI_pe0_ms103.bval')
                copyfile(fp + '/' + sub + '/anat/dwi/recon/DTI_pe0_ms103.bvec', 
                         destfp + '/' + sub + '/raw/DTI_pe0_ms103.bvec')
                copyfile(fp + '/' + sub + '/anat/dwi/recon/DTI_pe1.nii.gz', destfp + '/' + sub + '/raw/DTI_pe1.nii.gz')
                copyfile(fp + '/' + sub + '/anat/dwi/recon/DTI_pe1.bval', 
                         destfp + '/' + sub + '/raw/DTI_pe1.bval')
                copyfile(fp + '/' + sub + '/anat/dwi/recon/DTI_pe1.bvec', 
                         destfp + '/' + sub + '/raw/DTI_pe1.bvec')
    else:
        print('Original data not found for {}'.format(sub))
# Out:
# Data found for 1005-L-T2
# Checking directories for 1005-L-T2
# Subject folder created for 1005-L-T2
# Raw folder created for 1005-L-T2
# pe0 copied over
# pe1 also copied over
# Data found for 1010-L-T2
# Unwarping and eddy correction already completed for 1010-L-T2
# Data found for 1011-L-T2
# Checking directories for 1011-L-T2
# Subject folder created for 1011-L-T2
# Raw folder created for 1011-L-T2
# pe0 copied over
# pe1 also copied over
# Data found for 1017-L-T2
# Unwarping and eddy correction already completed for 1017-L-T2
# Data found for 1020-L-T2
# Unwarping and eddy correction already completed for 1020-L-T2
# Data found for 1023-L-T2
# Unwarping and eddy correction already completed for 1023-L-T2
# Data found for 1027-L-T2
# Unwarping and eddy correction already completed for 1027-L-T2
# Data found for 1028-L-T2
# Checking directories for 1028-L-T2
# Subject folder created for 1028-L-T2
# Raw folder created for 1028-L-T2
# pe0 copied over
# pe1 also copied over
# Original data not found for 1033-L-T2
# Data found for 1036-L-T2
# Unwarping and eddy correction already completed for 1036-L-T2
# Data found for 1037-L-T2
# Unwarping and eddy correction already completed for 1037-L-T2
# Data found for 1038-L-T2
# Checking directories for 1038-L-T2
# Subject folder created for 1038-L-T2
# Raw folder created for 1038-L-T2
# pe0 copied over
# pe1 also copied over
# Data found for 1042-L-T2
# Checking directories for 1042-L-T2
# Subject folder created for 1042-L-T2
# Raw folder created for 1042-L-T2
# pe0 copied over
# pe1 also copied over
# Data found for 1043-L-T2
# Checking directories for 1043-L-T2
# Subject folder created for 1043-L-T2
# Raw folder created for 1043-L-T2
# pe0 copied over
# pe1 also copied over
# Original data not found for 1050-L-T2
# Data found for 1053-L-T2
# Checking directories for 1053-L-T2
# Subject folder created for 1053-L-T2
# Raw folder created for 1053-L-T2
# pe0 copied over
# pe1 also copied over
# Data found for 1057-L-T2
# Checking directories for 1057-L-T2
# Subject folder created for 1057-L-T2
# Raw folder created for 1057-L-T2
# pe0 copied over
# pe1 also copied over
# Original data not found for 1060-L-T2
# Original data not found for 1068-L-T2
# Original data not found for 1069-L-T2

# %%
for sub in ready_to_run:
    dest = destfp + '/' + sub + '/'
    pe1_nii = destfp + '/' + sub + '/raw/DTI_pe1.nii.gz'
    pe1_bvec = destfp + '/' + sub + '/raw/DTI_pe1.bvec'
    pe1_bval = destfp + '/' + sub + '/raw/DTI_pe1.bval'
    pe0_nii = destfp + '/' + sub + '/raw/DTI_pe0_ms103.nii.gz'
    pe0_bvec = destfp + '/' + sub + '/raw/DTI_pe0_ms103.bvec'
    pe0_bval = destfp + '/' + sub + '/raw/DTI_pe0_ms103.bval'
    fslroi = pe.MapNode(interface = fsl.ExtractROI(t_min = 0, t_size = 1),
                       name = 'fslroi',
                       iterfield = ["in_file"])
    fslroi.inputs.in_file = [pe1_nii, pe0_nii]
    fslroi.outputs.roi_file = [dest + 'pe1_b.nii.gz', dest + 'pe0_b.nii.gz']
    fslmerge = pe.Node(interface = fsl.Merge(dimension = 't', merged_file = dest + 'bud.nii.gz'), name = 'fslmerge')
    topup = pe.Node(interface = fsl.TOPUP(encoding_file = params, out_base = dest + 'DTI_topup'),
                    name = 'topup')
    
    anatflow_l = pe.Workflow(name = "anatflow_l")
    anatflow_l.connect([(fslroi, fslmerge, [('roi_file', 'in_files')]),
                        (fslmerge, topup, [('merged_file', 'in_file')])
                       ])
    anatflow_l.base_dir = workflow_dir
    anatflow_l.write_graph(graph2use = 'flat')
    anatflow_l.run('MultiProc', plugin_args={'n_procs': 1})
# Out:
# 180726-17:05:58,893 workflow INFO:
# 	 Generated workflow graph: /Volumes/iang/active/BABIES/BABIES_diffusion/workflows/anatflow_l/graph.png (graph2use=flat, simple_form=True).
# 180726-17:05:58,917 workflow INFO:
# 	 Workflow anatflow_l settings: ['check', 'execution', 'logging', 'monitoring']
# 180726-17:05:59,7 workflow INFO:
# 	 Running in parallel.
# 180726-17:05:59,11 workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 28.80/28.80, Free processors: 1/1.
# 180726-17:06:01,12 workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 2 jobs ready. Free memory (GB): 28.80/28.80, Free processors: 1/1.
# 180726-17:06:01,68 workflow INFO:
# 	 [Node] Setting-up "_fslroi0" in "/Volumes/iang/active/BABIES/BABIES_diffusion/workflows/anatflow_l/fslroi/mapflow/_fslroi0".
# 180726-17:06:01,153 workflow INFO:
# 	 [Node] Running "_fslroi0" ("nipype.interfaces.fsl.utils.ExtractROI"), a CommandLine Interface with command:
# fslroi /Volumes/iang/active/BABIES/BABIES_diffusion/subjsDir/Newborn/1005-L-T2/raw/DTI_pe1.nii.gz /Volumes/iang/active/BABIES/BABIES_diffusion/scripts/DTI_pe1_roi.nii.gz 0 1
# 180726-17:06:03,16 workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 1 jobs ready. Free memory (GB): 28.60/28.80, Free processors: 0/1.
#                      Currently running:
#                        * _fslroi0
# 180726-17:06:03,356 workflow INFO:
# 	 [Node] Finished "_fslroi0".
# 180726-17:06:05,18 workflow INFO:
# 	 [Job 3] Completed (_fslroi0).
# 180726-17:06:05,20 workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 28.80/28.80, Free processors: 1/1.
# 180726-17:06:05,75 workflow INFO:
# 	 [Node] Setting-up "_fslroi1" in "/Volumes/iang/active/BABIES/BABIES_diffusion/workflows/anatflow_l/fslroi/mapflow/_fslroi1".
# 180726-17:06:05,146 workflow INFO:
# 	 [Node] Running "_fslroi1" ("nipype.interfaces.fsl.utils.ExtractROI"), a CommandLine Interface with command:
# fslroi /Volumes/iang/active/BABIES/BABIES_diffusion/subjsDir/Newborn/1005-L-T2/raw/DTI_pe0_ms103.nii.gz /Volumes/iang/active/BABIES/BABIES_diffusion/scripts/DTI_pe0_ms103_roi.nii.gz 0 1
# 180726-17:06:07,19 workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 0 jobs ready. Free memory (GB): 28.60/28.80, Free processors: 0/1.
#                      Currently running:
#                        * _fslroi1
# 180726-17:06:32,715 workflow INFO:
# 	 [Node] Finished "_fslroi1".
# 180726-17:06:33,32 workflow INFO:
# 	 [Job 4] Completed (_fslroi1).
# 180726-17:06:33,34 workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 28.80/28.80, Free processors: 1/1.
# 180726-17:06:33,97 workflow INFO:
# 	 [Node] Setting-up "anatflow_l.fslroi" in "/Volumes/iang/active/BABIES/BABIES_diffusion/workflows/anatflow_l/fslroi".
# 180726-17:06:33,138 workflow INFO:
# 	 [Node] Setting-up "_fslroi0" in "/Volumes/iang/active/BABIES/BABIES_diffusion/workflows/anatflow_l/fslroi/mapflow/_fslroi0".
# 180726-17:06:33,198 workflow INFO:
# 	 [Node] Cached "_fslroi0" - collecting precomputed outputs
# 180726-17:06:33,203 workflow INFO:
# 	 [Node] "_fslroi0" found cached.
# 180726-17:06:33,208 workflow INFO:
# 	 [Node] Setting-up "_fslroi1" in "/Volumes/iang/active/BABIES/BABIES_diffusion/workflows/anatflow_l/fslroi/mapflow/_fslroi1".
# 180726-17:06:33,260 workflow INFO:
# 	 [Node] Cached "_fslroi1" - collecting precomputed outputs
# 180726-17:06:33,263 workflow INFO:
# 	 [Node] "_fslroi1" found cached.
# 180726-17:06:33,445 workflow INFO:
# 	 [Node] Finished "anatflow_l.fslroi".
# 180726-17:06:35,35 workflow INFO:
# 	 [Job 0] Completed (anatflow_l.fslroi).
# 180726-17:06:35,37 workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 28.80/28.80, Free processors: 1/1.
# 180726-17:06:35,104 workflow INFO:
# 	 [Node] Setting-up "anatflow_l.fslmerge" in "/Volumes/iang/active/BABIES/BABIES_diffusion/workflows/anatflow_l/fslmerge".
# 180726-17:06:35,169 workflow INFO:
# 	 [Node] Running "fslmerge" ("nipype.interfaces.fsl.utils.Merge"), a CommandLine Interface with command:
# fslmerge -t /Volumes/iang/active/BABIES/BABIES_diffusion/subjsDir/Newborn/1005-L-T2/bud.nii.gz /Volumes/iang/active/BABIES/BABIES_diffusion/workflows/anatflow_l/fslroi/mapflow/_fslroi0/DTI_pe1_roi.nii.gz /Volumes/iang/active/BABIES/BABIES_diffusion/workflows/anatflow_l/fslroi/mapflow/_fslroi1/DTI_pe0_ms103_roi.nii.gz
# 180726-17:06:36,843 workflow INFO:
# 	 [Node] Finished "anatflow_l.fslmerge".
# 180726-17:06:37,36 workflow INFO:
# 	 [Job 1] Completed (anatflow_l.fslmerge).
# 180726-17:06:37,39 workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 28.80/28.80, Free processors: 1/1.
# 180726-17:06:37,103 workflow INFO:
# 	 [Node] Setting-up "anatflow_l.topup" in "/Volumes/iang/active/BABIES/BABIES_diffusion/workflows/anatflow_l/topup".
# 180726-17:06:37,170 workflow INFO:
# 	 [Node] Running "topup" ("nipype.interfaces.fsl.epi.TOPUP"), a CommandLine Interface with command:
# topup --config=b02b0.cnf --datain=/Volumes/iang/active/BABIES/BABIES_diffusion/subjsDir/acq_params.txt --imain=/Volumes/iang/active/BABIES/BABIES_diffusion/subjsDir/Newborn/1005-L-T2/bud.nii.gz --out=/Volumes/iang/active/BABIES/BABIES_diffusion/subjsDir/Newborn/1005-L-T2/DTI_topup --iout=bud_corrected.nii.gz --fout=bud_field.nii.gz --jacout=jac --logout=bud_topup.log --rbmout=xfm --dfout=warpfield
# 180726-17:06:39,37 workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 0 jobs ready. Free memory (GB): 28.60/28.80, Free processors: 0/1.
#                      Currently running:
#                        * anatflow_l.topup
# 180726-17:10:46,573 workflow INFO:
# 	 [Node] Finished "anatflow_l.topup".
# 180726-17:10:47,240 workflow INFO:
# 	 [Job 2] Completed (anatflow_l.topup).
# 180726-17:10:47,242 workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 0 jobs ready. Free memory (GB): 28.80/28.80, Free processors: 1/1.
# 180726-17:10:49,720 workflow INFO:
# 	 Generated workflow graph: /Volumes/iang/active/BABIES/BABIES_diffusion/workflows/anatflow_l/graph.png (graph2use=flat, simple_form=True).
# 180726-17:10:49,743 workflow INFO:
# 	 Workflow anatflow_l settings: ['check', 'execution', 'logging', 'monitoring']
# 180726-17:10:49,828 workflow INFO:
# 	 Running in parallel.
# 180726-17:10:49,831 workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 28.80/28.80, Free processors: 1/1.
# 180726-17:10:51,832 workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 2 jobs ready. Free memory (GB): 28.80/28.80, Free processors: 1/1.
# 180726-17:10:51,889 workflow INFO:
# 	 [Node] Outdated cache found for "_fslroi0".
# 180726-17:10:51,894 workflow INFO:
# 	 [Node] Setting-up "_fslroi0" in "/Volumes/iang/active/BABIES/BABIES_diffusion/workflows/anatflow_l/fslroi/mapflow/_fslroi0".
# 180726-17:10:51,901 workflow INFO:
# 	 [Node] Outdated cache found for "_fslroi0".
# 180726-17:10:52,116 workflow INFO:
# 	 [Node] Running "_fslroi0" ("nipype.interfaces.fsl.utils.ExtractROI"), a CommandLine Interface with command:
# fslroi /Volumes/iang/active/BABIES/BABIES_diffusion/subjsDir/Newborn/1011-L-T2/raw/DTI_pe1.nii.gz /Volumes/iang/active/BABIES/BABIES_diffusion/scripts/DTI_pe1_roi.nii.gz 0 1
# 180726-17:10:53,832 workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 1 jobs ready. Free memory (GB): 28.60/28.80, Free processors: 0/1.
#                      Currently running:
#                        * _fslroi0
# 180726-17:10:54,500 workflow INFO:
# 	 [Node] Finished "_fslroi0".
# 180726-17:10:55,837 workflow INFO:
# 	 [Job 3] Completed (_fslroi0).
# 180726-17:10:55,839 workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 28.80/28.80, Free processors: 1/1.
# 180726-17:10:55,897 workflow INFO:
# 	 [Node] Outdated cache found for "_fslroi1".
# 180726-17:10:55,899 workflow INFO:
# 	 [Node] Setting-up "_fslroi1" in "/Volumes/iang/active/BABIES/BABIES_diffusion/workflows/anatflow_l/fslroi/mapflow/_fslroi1".
# 180726-17:10:55,904 workflow INFO:
# 	 [Node] Outdated cache found for "_fslroi1".
# 180726-17:10:56,131 workflow INFO:
# 	 [Node] Running "_fslroi1" ("nipype.interfaces.fsl.utils.ExtractROI"), a CommandLine Interface with command:
# fslroi /Volumes/iang/active/BABIES/BABIES_diffusion/subjsDir/Newborn/1011-L-T2/raw/DTI_pe0_ms103.nii.gz /Volumes/iang/active/BABIES/BABIES_diffusion/scripts/DTI_pe0_ms103_roi.nii.gz 0 1
# 180726-17:10:57,837 workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 0 jobs ready. Free memory (GB): 28.60/28.80, Free processors: 0/1.
#                      Currently running:
#                        * _fslroi1
# 180726-17:11:00,988 workflow INFO:
# 	 [Node] Finished "_fslroi1".
# 180726-17:11:01,838 workflow INFO:
# 	 [Job 4] Completed (_fslroi1).
# 180726-17:11:01,841 workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 28.80/28.80, Free processors: 1/1.
# 180726-17:11:01,902 workflow INFO:
# 	 [Node] Outdated cache found for "anatflow_l.fslroi".
# 180726-17:11:01,905 workflow INFO:
# 	 [Node] Setting-up "anatflow_l.fslroi" in "/Volumes/iang/active/BABIES/BABIES_diffusion/workflows/anatflow_l/fslroi".
# 180726-17:11:01,911 workflow INFO:
# 	 [Node] Outdated cache found for "anatflow_l.fslroi".
# 180726-17:11:01,981 workflow INFO:
# 	 [Node] Setting-up "_fslroi0" in "/Volumes/iang/active/BABIES/BABIES_diffusion/workflows/anatflow_l/fslroi/mapflow/_fslroi0".
# 180726-17:11:02,78 workflow INFO:
# 	 [Node] Cached "_fslroi0" - collecting precomputed outputs
# 180726-17:11:02,82 workflow INFO:
# 	 [Node] "_fslroi0" found cached.
# 180726-17:11:02,87 workflow INFO:
# 	 [Node] Setting-up "_fslroi1" in "/Volumes/iang/active/BABIES/BABIES_diffusion/workflows/anatflow_l/fslroi/mapflow/_fslroi1".
# 180726-17:11:02,140 workflow INFO:
# 	 [Node] Cached "_fslroi1" - collecting precomputed outputs
# 180726-17:11:02,144 workflow INFO:
# 	 [Node] "_fslroi1" found cached.
# 180726-17:11:02,198 workflow INFO:
# 	 [Node] Finished "anatflow_l.fslroi".
# 180726-17:11:03,843 workflow INFO:
# 	 [Job 0] Completed (anatflow_l.fslroi).
# 180726-17:11:03,845 workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 28.80/28.80, Free processors: 1/1.
# 180726-17:11:03,907 workflow INFO:
# 	 [Node] Outdated cache found for "anatflow_l.fslmerge".
# 180726-17:11:03,910 workflow INFO:
# 	 [Node] Setting-up "anatflow_l.fslmerge" in "/Volumes/iang/active/BABIES/BABIES_diffusion/workflows/anatflow_l/fslmerge".
# 180726-17:11:03,915 workflow INFO:
# 	 [Node] Outdated cache found for "anatflow_l.fslmerge".
# 180726-17:11:04,129 workflow INFO:
# 	 [Node] Running "fslmerge" ("nipype.interfaces.fsl.utils.Merge"), a CommandLine Interface with command:
# fslmerge -t /Volumes/iang/active/BABIES/BABIES_diffusion/subjsDir/Newborn/1011-L-T2/bud.nii.gz /Volumes/iang/active/BABIES/BABIES_diffusion/workflows/anatflow_l/fslroi/mapflow/_fslroi0/DTI_pe1_roi.nii.gz /Volumes/iang/active/BABIES/BABIES_diffusion/workflows/anatflow_l/fslroi/mapflow/_fslroi1/DTI_pe0_ms103_roi.nii.gz
# 180726-17:11:05,771 workflow INFO:
# 	 [Node] Finished "anatflow_l.fslmerge".
# 180726-17:11:05,847 workflow INFO:
# 	 [Job 1] Completed (anatflow_l.fslmerge).
# 180726-17:11:05,849 workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 28.80/28.80, Free processors: 1/1.
# 180726-17:11:05,909 workflow INFO:
# 	 [Node] Outdated cache found for "anatflow_l.topup".
# 180726-17:11:05,911 workflow INFO:
# 	 [Node] Setting-up "anatflow_l.topup" in "/Volumes/iang/active/BABIES/BABIES_diffusion/workflows/anatflow_l/topup".
# 180726-17:11:05,917 workflow INFO:
# 	 [Node] Outdated cache found for "anatflow_l.topup".
# 180726-17:11:06,261 workflow INFO:
# 	 [Node] Running "topup" ("nipype.interfaces.fsl.epi.TOPUP"), a CommandLine Interface with command:
# topup --config=b02b0.cnf --datain=/Volumes/iang/active/BABIES/BABIES_diffusion/subjsDir/acq_params.txt --imain=/Volumes/iang/active/BABIES/BABIES_diffusion/subjsDir/Newborn/1011-L-T2/bud.nii.gz --out=/Volumes/iang/active/BABIES/BABIES_diffusion/subjsDir/Newborn/1011-L-T2/DTI_topup --iout=bud_corrected.nii.gz --fout=bud_field.nii.gz --jacout=jac --logout=bud_topup.log --rbmout=xfm --dfout=warpfield
# 180726-17:11:07,851 workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 0 jobs ready. Free memory (GB): 28.60/28.80, Free processors: 0/1.
#                      Currently running:
#                        * anatflow_l.topup
# 180726-17:15:11,867 workflow INFO:
# 	 [Node] Finished "anatflow_l.topup".
# 180726-17:15:12,66 workflow INFO:
# 	 [Job 2] Completed (anatflow_l.topup).
# 180726-17:15:12,68 workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 0 jobs ready. Free memory (GB): 28.80/28.80, Free processors: 1/1.
# 180726-17:15:14,554 workflow INFO:
# 	 Generated workflow graph: /Volumes/iang/active/BABIES/BABIES_diffusion/workflows/anatflow_l/graph.png (graph2use=flat, simple_form=True).
# 180726-17:15:14,577 workflow INFO:
# 	 Workflow anatflow_l settings: ['check', 'execution', 'logging', 'monitoring']
# 180726-17:15:14,660 workflow INFO:
# 	 Running in parallel.
# 180726-17:15:14,663 workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 28.80/28.80, Free processors: 1/1.
# 180726-17:15:16,667 workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 2 jobs ready. Free memory (GB): 28.80/28.80, Free processors: 1/1.
# 180726-17:15:16,726 workflow INFO:
# 	 [Node] Outdated cache found for "_fslroi0".
# 180726-17:15:16,731 workflow INFO:
# 	 [Node] Setting-up "_fslroi0" in "/Volumes/iang/active/BABIES/BABIES_diffusion/workflows/anatflow_l/fslroi/mapflow/_fslroi0".
# 180726-17:15:16,739 workflow INFO:
# 	 [Node] Outdated cache found for "_fslroi0".
# 180726-17:15:16,976 workflow INFO:
# 	 [Node] Running "_fslroi0" ("nipype.interfaces.fsl.utils.ExtractROI"), a CommandLine Interface with command:
# fslroi /Volumes/iang/active/BABIES/BABIES_diffusion/subjsDir/Newborn/1028-L-T2/raw/DTI_pe1.nii.gz /Volumes/iang/active/BABIES/BABIES_diffusion/scripts/DTI_pe1_roi.nii.gz 0 1
# 180726-17:15:18,667 workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 1 jobs ready. Free memory (GB): 28.60/28.80, Free processors: 0/1.
#                      Currently running:
#                        * _fslroi0
# 180726-17:15:19,343 workflow INFO:
# 	 [Node] Finished "_fslroi0".
# 180726-17:15:20,669 workflow INFO:
# 	 [Job 3] Completed (_fslroi0).
# 180726-17:15:20,671 workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 28.80/28.80, Free processors: 1/1.
# 180726-17:15:20,728 workflow INFO:
# 	 [Node] Outdated cache found for "_fslroi1".
# 180726-17:15:20,730 workflow INFO:
# 	 [Node] Setting-up "_fslroi1" in "/Volumes/iang/active/BABIES/BABIES_diffusion/workflows/anatflow_l/fslroi/mapflow/_fslroi1".
# 180726-17:15:20,735 workflow INFO:
# 	 [Node] Outdated cache found for "_fslroi1".
# 180726-17:15:20,998 workflow INFO:
# 	 [Node] Running "_fslroi1" ("nipype.interfaces.fsl.utils.ExtractROI"), a CommandLine Interface with command:
# fslroi /Volumes/iang/active/BABIES/BABIES_diffusion/subjsDir/Newborn/1028-L-T2/raw/DTI_pe0_ms103.nii.gz /Volumes/iang/active/BABIES/BABIES_diffusion/scripts/DTI_pe0_ms103_roi.nii.gz 0 1
# 180726-17:15:22,671 workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 0 jobs ready. Free memory (GB): 28.60/28.80, Free processors: 0/1.
#                      Currently running:
#                        * _fslroi1
# 180726-17:15:51,338 workflow INFO:
# 	 [Node] Finished "_fslroi1".
# 180726-17:15:52,694 workflow INFO:
# 	 [Job 4] Completed (_fslroi1).
# 180726-17:15:52,696 workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 28.80/28.80, Free processors: 1/1.
# 180726-17:15:52,759 workflow INFO:
# 	 [Node] Outdated cache found for "anatflow_l.fslroi".
# 180726-17:15:52,762 workflow INFO:
# 	 [Node] Setting-up "anatflow_l.fslroi" in "/Volumes/iang/active/BABIES/BABIES_diffusion/workflows/anatflow_l/fslroi".
# 180726-17:15:52,767 workflow INFO:
# 	 [Node] Outdated cache found for "anatflow_l.fslroi".
# 180726-17:15:52,827 workflow INFO:
# 	 [Node] Setting-up "_fslroi0" in "/Volumes/iang/active/BABIES/BABIES_diffusion/workflows/anatflow_l/fslroi/mapflow/_fslroi0".
# 180726-17:15:52,890 workflow INFO:
# 	 [Node] Cached "_fslroi0" - collecting precomputed outputs
# 180726-17:15:52,894 workflow INFO:
# 	 [Node] "_fslroi0" found cached.
# 180726-17:15:52,899 workflow INFO:
# 	 [Node] Setting-up "_fslroi1" in "/Volumes/iang/active/BABIES/BABIES_diffusion/workflows/anatflow_l/fslroi/mapflow/_fslroi1".
# 180726-17:15:52,951 workflow INFO:
# 	 [Node] Cached "_fslroi1" - collecting precomputed outputs
# 180726-17:15:52,955 workflow INFO:
# 	 [Node] "_fslroi1" found cached.
# 180726-17:15:53,10 workflow INFO:
# 	 [Node] Finished "anatflow_l.fslroi".
# 180726-17:15:54,695 workflow INFO:
# 	 [Job 0] Completed (anatflow_l.fslroi).
# 180726-17:15:54,698 workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 28.80/28.80, Free processors: 1/1.
# 180726-17:15:54,763 workflow INFO:
# 	 [Node] Outdated cache found for "anatflow_l.fslmerge".
# 180726-17:15:54,766 workflow INFO:
# 	 [Node] Setting-up "anatflow_l.fslmerge" in "/Volumes/iang/active/BABIES/BABIES_diffusion/workflows/anatflow_l/fslmerge".
# 180726-17:15:54,771 workflow INFO:
# 	 [Node] Outdated cache found for "anatflow_l.fslmerge".
# 180726-17:15:55,31 workflow INFO:
# 	 [Node] Running "fslmerge" ("nipype.interfaces.fsl.utils.Merge"), a CommandLine Interface with command:
# fslmerge -t /Volumes/iang/active/BABIES/BABIES_diffusion/subjsDir/Newborn/1028-L-T2/bud.nii.gz /Volumes/iang/active/BABIES/BABIES_diffusion/workflows/anatflow_l/fslroi/mapflow/_fslroi0/DTI_pe1_roi.nii.gz /Volumes/iang/active/BABIES/BABIES_diffusion/workflows/anatflow_l/fslroi/mapflow/_fslroi1/DTI_pe0_ms103_roi.nii.gz
# 180726-17:15:56,696 workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 0 jobs ready. Free memory (GB): 28.60/28.80, Free processors: 0/1.
#                      Currently running:
#                        * anatflow_l.fslmerge
# 180726-17:15:56,748 workflow INFO:
# 	 [Node] Finished "anatflow_l.fslmerge".
# 180726-17:15:58,699 workflow INFO:
# 	 [Job 1] Completed (anatflow_l.fslmerge).
# 180726-17:15:58,701 workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 28.80/28.80, Free processors: 1/1.
# 180726-17:15:58,768 workflow INFO:
# 	 [Node] Outdated cache found for "anatflow_l.topup".
# 180726-17:15:58,771 workflow INFO:
# 	 [Node] Setting-up "anatflow_l.topup" in "/Volumes/iang/active/BABIES/BABIES_diffusion/workflows/anatflow_l/topup".
# 180726-17:15:58,776 workflow INFO:
# 	 [Node] Outdated cache found for "anatflow_l.topup".
# 180726-17:15:59,59 workflow INFO:
# 	 [Node] Running "topup" ("nipype.interfaces.fsl.epi.TOPUP"), a CommandLine Interface with command:
# topup --config=b02b0.cnf --datain=/Volumes/iang/active/BABIES/BABIES_diffusion/subjsDir/acq_params.txt --imain=/Volumes/iang/active/BABIES/BABIES_diffusion/subjsDir/Newborn/1028-L-T2/bud.nii.gz --out=/Volumes/iang/active/BABIES/BABIES_diffusion/subjsDir/Newborn/1028-L-T2/DTI_topup --iout=bud_corrected.nii.gz --fout=bud_field.nii.gz --jacout=jac --logout=bud_topup.log --rbmout=xfm --dfout=warpfield
# 180726-17:16:00,702 workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 0 jobs ready. Free memory (GB): 28.60/28.80, Free processors: 0/1.
#                      Currently running:
#                        * anatflow_l.topup
# 180726-17:20:03,262 workflow INFO:
# 	 [Node] Finished "anatflow_l.topup".
# 180726-17:20:04,949 workflow INFO:
# 	 [Job 2] Completed (anatflow_l.topup).
# 180726-17:20:04,951 workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 0 jobs ready. Free memory (GB): 28.80/28.80, Free processors: 1/1.
# 180726-17:20:07,419 workflow INFO:
# 	 Generated workflow graph: /Volumes/iang/active/BABIES/BABIES_diffusion/workflows/anatflow_l/graph.png (graph2use=flat, simple_form=True).
# 180726-17:20:07,443 workflow INFO:
# 	 Workflow anatflow_l settings: ['check', 'execution', 'logging', 'monitoring']
# 180726-17:20:07,527 workflow INFO:
# 	 Running in parallel.
# 180726-17:20:07,530 workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 28.80/28.80, Free processors: 1/1.
# 180726-17:20:09,530 workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 2 jobs ready. Free memory (GB): 28.80/28.80, Free processors: 1/1.
# 180726-17:20:09,587 workflow INFO:
# 	 [Node] Outdated cache found for "_fslroi0".
# 180726-17:20:09,592 workflow INFO:
# 	 [Node] Setting-up "_fslroi0" in "/Volumes/iang/active/BABIES/BABIES_diffusion/workflows/anatflow_l/fslroi/mapflow/_fslroi0".
# 180726-17:20:09,600 workflow INFO:
# 	 [Node] Outdated cache found for "_fslroi0".
# 180726-17:20:09,851 workflow INFO:
# 	 [Node] Running "_fslroi0" ("nipype.interfaces.fsl.utils.ExtractROI"), a CommandLine Interface with command:
# fslroi /Volumes/iang/active/BABIES/BABIES_diffusion/subjsDir/Newborn/1038-L-T2/raw/DTI_pe1.nii.gz /Volumes/iang/active/BABIES/BABIES_diffusion/scripts/DTI_pe1_roi.nii.gz 0 1
# 180726-17:20:11,187 workflow INFO:
# 	 [Node] Finished "_fslroi0".
# 180726-17:20:11,531 workflow INFO:
# 	 [Job 3] Completed (_fslroi0).
# 180726-17:20:11,532 workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 28.80/28.80, Free processors: 1/1.
# 180726-17:20:11,591 workflow INFO:
# 	 [Node] Outdated cache found for "_fslroi1".
# 180726-17:20:11,593 workflow INFO:
# 	 [Node] Setting-up "_fslroi1" in "/Volumes/iang/active/BABIES/BABIES_diffusion/workflows/anatflow_l/fslroi/mapflow/_fslroi1".
# 180726-17:20:11,598 workflow INFO:
# 	 [Node] Outdated cache found for "_fslroi1".
# 180726-17:20:11,833 workflow INFO:
# 	 [Node] Running "_fslroi1" ("nipype.interfaces.fsl.utils.ExtractROI"), a CommandLine Interface with command:
# fslroi /Volumes/iang/active/BABIES/BABIES_diffusion/subjsDir/Newborn/1038-L-T2/raw/DTI_pe0_ms103.nii.gz /Volumes/iang/active/BABIES/BABIES_diffusion/scripts/DTI_pe0_ms103_roi.nii.gz 0 1
# 180726-17:20:13,532 workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 0 jobs ready. Free memory (GB): 28.60/28.80, Free processors: 0/1.
#                      Currently running:
#                        * _fslroi1
# 180726-17:20:22,661 workflow INFO:
# 	 [Node] Finished "_fslroi1".
# 180726-17:20:23,541 workflow INFO:
# 	 [Job 4] Completed (_fslroi1).
# 180726-17:20:23,543 workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 28.80/28.80, Free processors: 1/1.
# 180726-17:20:23,601 workflow INFO:
# 	 [Node] Outdated cache found for "anatflow_l.fslroi".
# 180726-17:20:23,603 workflow INFO:
# 	 [Node] Setting-up "anatflow_l.fslroi" in "/Volumes/iang/active/BABIES/BABIES_diffusion/workflows/anatflow_l/fslroi".
# 180726-17:20:23,609 workflow INFO:
# 	 [Node] Outdated cache found for "anatflow_l.fslroi".
# 180726-17:20:23,669 workflow INFO:
# 	 [Node] Setting-up "_fslroi0" in "/Volumes/iang/active/BABIES/BABIES_diffusion/workflows/anatflow_l/fslroi/mapflow/_fslroi0".
# 180726-17:20:23,728 workflow INFO:
# 	 [Node] Cached "_fslroi0" - collecting precomputed outputs
# 180726-17:20:23,733 workflow INFO:
# 	 [Node] "_fslroi0" found cached.
# 180726-17:20:23,737 workflow INFO:
# 	 [Node] Setting-up "_fslroi1" in "/Volumes/iang/active/BABIES/BABIES_diffusion/workflows/anatflow_l/fslroi/mapflow/_fslroi1".
# 180726-17:20:23,811 workflow INFO:
# 	 [Node] Cached "_fslroi1" - collecting precomputed outputs
# 180726-17:20:23,815 workflow INFO:
# 	 [Node] "_fslroi1" found cached.
# 180726-17:20:23,871 workflow INFO:
# 	 [Node] Finished "anatflow_l.fslroi".
# 180726-17:20:25,541 workflow INFO:
# 	 [Job 0] Completed (anatflow_l.fslroi).
# 180726-17:20:25,543 workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 28.80/28.80, Free processors: 1/1.
# 180726-17:20:25,608 workflow INFO:
# 	 [Node] Outdated cache found for "anatflow_l.fslmerge".
# 180726-17:20:25,611 workflow INFO:
# 	 [Node] Setting-up "anatflow_l.fslmerge" in "/Volumes/iang/active/BABIES/BABIES_diffusion/workflows/anatflow_l/fslmerge".
# 180726-17:20:25,615 workflow INFO:
# 	 [Node] Outdated cache found for "anatflow_l.fslmerge".
# 180726-17:20:25,828 workflow INFO:
# 	 [Node] Running "fslmerge" ("nipype.interfaces.fsl.utils.Merge"), a CommandLine Interface with command:
# fslmerge -t /Volumes/iang/active/BABIES/BABIES_diffusion/subjsDir/Newborn/1038-L-T2/bud.nii.gz /Volumes/iang/active/BABIES/BABIES_diffusion/workflows/anatflow_l/fslroi/mapflow/_fslroi0/DTI_pe1_roi.nii.gz /Volumes/iang/active/BABIES/BABIES_diffusion/workflows/anatflow_l/fslroi/mapflow/_fslroi1/DTI_pe0_ms103_roi.nii.gz
# 180726-17:20:27,391 workflow INFO:
# 	 [Node] Finished "anatflow_l.fslmerge".
# 180726-17:20:27,541 workflow INFO:
# 	 [Job 1] Completed (anatflow_l.fslmerge).
# 180726-17:20:27,543 workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 28.80/28.80, Free processors: 1/1.
# 180726-17:20:27,607 workflow INFO:
# 	 [Node] Outdated cache found for "anatflow_l.topup".
# 180726-17:20:27,610 workflow INFO:
# 	 [Node] Setting-up "anatflow_l.topup" in "/Volumes/iang/active/BABIES/BABIES_diffusion/workflows/anatflow_l/topup".
# 180726-17:20:27,615 workflow INFO:
# 	 [Node] Outdated cache found for "anatflow_l.topup".
# 180726-17:20:28,119 workflow INFO:
# 	 [Node] Running "topup" ("nipype.interfaces.fsl.epi.TOPUP"), a CommandLine Interface with command:
# topup --config=b02b0.cnf --datain=/Volumes/iang/active/BABIES/BABIES_diffusion/subjsDir/acq_params.txt --imain=/Volumes/iang/active/BABIES/BABIES_diffusion/subjsDir/Newborn/1038-L-T2/bud.nii.gz --out=/Volumes/iang/active/BABIES/BABIES_diffusion/subjsDir/Newborn/1038-L-T2/DTI_topup --iout=bud_corrected.nii.gz --fout=bud_field.nii.gz --jacout=jac --logout=bud_topup.log --rbmout=xfm --dfout=warpfield
# 180726-17:20:29,542 workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 0 jobs ready. Free memory (GB): 28.60/28.80, Free processors: 0/1.
#                      Currently running:
#                        * anatflow_l.topup
# 180726-17:24:28,83 workflow INFO:
# 	 [Node] Finished "anatflow_l.topup".
# 180726-17:24:29,811 workflow INFO:
# 	 [Job 2] Completed (anatflow_l.topup).
# 180726-17:24:29,813 workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 0 jobs ready. Free memory (GB): 28.80/28.80, Free processors: 1/1.
# 180726-17:24:32,288 workflow INFO:
# 	 Generated workflow graph: /Volumes/iang/active/BABIES/BABIES_diffusion/workflows/anatflow_l/graph.png (graph2use=flat, simple_form=True).
# 180726-17:24:32,312 workflow INFO:
# 	 Workflow anatflow_l settings: ['check', 'execution', 'logging', 'monitoring']
# 180726-17:24:32,398 workflow INFO:
# 	 Running in parallel.
# 180726-17:24:32,402 workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 28.80/28.80, Free processors: 1/1.
# 180726-17:24:34,404 workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 2 jobs ready. Free memory (GB): 28.80/28.80, Free processors: 1/1.
# 180726-17:24:34,462 workflow INFO:
# 	 [Node] Outdated cache found for "_fslroi0".
# 180726-17:24:34,467 workflow INFO:
# 	 [Node] Setting-up "_fslroi0" in "/Volumes/iang/active/BABIES/BABIES_diffusion/workflows/anatflow_l/fslroi/mapflow/_fslroi0".
# 180726-17:24:34,475 workflow INFO:
# 	 [Node] Outdated cache found for "_fslroi0".
# 180726-17:24:34,773 workflow INFO:
# 	 [Node] Running "_fslroi0" ("nipype.interfaces.fsl.utils.ExtractROI"), a CommandLine Interface with command:
# fslroi /Volumes/iang/active/BABIES/BABIES_diffusion/subjsDir/Newborn/1042-L-T2/raw/DTI_pe1.nii.gz /Volumes/iang/active/BABIES/BABIES_diffusion/scripts/DTI_pe1_roi.nii.gz 0 1
# 180726-17:24:36,404 workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 1 jobs ready. Free memory (GB): 28.60/28.80, Free processors: 0/1.
#                      Currently running:
#                        * _fslroi0
# 180726-17:24:37,209 workflow INFO:
# 	 [Node] Finished "_fslroi0".
# 180726-17:24:38,406 workflow INFO:
# 	 [Job 3] Completed (_fslroi0).
# 180726-17:24:38,408 workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 28.80/28.80, Free processors: 1/1.
# 180726-17:24:38,463 workflow INFO:
# 	 [Node] Outdated cache found for "_fslroi1".
# 180726-17:24:38,465 workflow INFO:
# 	 [Node] Setting-up "_fslroi1" in "/Volumes/iang/active/BABIES/BABIES_diffusion/workflows/anatflow_l/fslroi/mapflow/_fslroi1".
# 180726-17:24:38,470 workflow INFO:
# 	 [Node] Outdated cache found for "_fslroi1".
# 180726-17:24:38,677 workflow INFO:
# 	 [Node] Running "_fslroi1" ("nipype.interfaces.fsl.utils.ExtractROI"), a CommandLine Interface with command:
# fslroi /Volumes/iang/active/BABIES/BABIES_diffusion/subjsDir/Newborn/1042-L-T2/raw/DTI_pe0_ms103.nii.gz /Volumes/iang/active/BABIES/BABIES_diffusion/scripts/DTI_pe0_ms103_roi.nii.gz 0 1
# 180726-17:24:40,407 workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 0 jobs ready. Free memory (GB): 28.60/28.80, Free processors: 0/1.
#                      Currently running:
#                        * _fslroi1
# 180726-17:25:08,23 workflow INFO:
# 	 [Node] Finished "_fslroi1".
# 180726-17:25:08,421 workflow INFO:
# 	 [Job 4] Completed (_fslroi1).
# 180726-17:25:08,423 workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 28.80/28.80, Free processors: 1/1.
# 180726-17:25:08,486 workflow INFO:
# 	 [Node] Outdated cache found for "anatflow_l.fslroi".
# 180726-17:25:08,489 workflow INFO:
# 	 [Node] Setting-up "anatflow_l.fslroi" in "/Volumes/iang/active/BABIES/BABIES_diffusion/workflows/anatflow_l/fslroi".
# 180726-17:25:08,495 workflow INFO:
# 	 [Node] Outdated cache found for "anatflow_l.fslroi".
# 180726-17:25:08,562 workflow INFO:
# 	 [Node] Setting-up "_fslroi0" in "/Volumes/iang/active/BABIES/BABIES_diffusion/workflows/anatflow_l/fslroi/mapflow/_fslroi0".
# 180726-17:25:08,614 workflow INFO:
# 	 [Node] Cached "_fslroi0" - collecting precomputed outputs
# 180726-17:25:08,618 workflow INFO:
# 	 [Node] "_fslroi0" found cached.
# 180726-17:25:08,622 workflow INFO:
# 	 [Node] Setting-up "_fslroi1" in "/Volumes/iang/active/BABIES/BABIES_diffusion/workflows/anatflow_l/fslroi/mapflow/_fslroi1".
# 180726-17:25:08,676 workflow INFO:
# 	 [Node] Cached "_fslroi1" - collecting precomputed outputs
# 180726-17:25:08,680 workflow INFO:
# 	 [Node] "_fslroi1" found cached.
# 180726-17:25:08,742 workflow INFO:
# 	 [Node] Finished "anatflow_l.fslroi".
# 180726-17:25:10,426 workflow INFO:
# 	 [Job 0] Completed (anatflow_l.fslroi).
# 180726-17:25:10,428 workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 28.80/28.80, Free processors: 1/1.
# 180726-17:25:10,492 workflow INFO:
# 	 [Node] Outdated cache found for "anatflow_l.fslmerge".
# 180726-17:25:10,495 workflow INFO:
# 	 [Node] Setting-up "anatflow_l.fslmerge" in "/Volumes/iang/active/BABIES/BABIES_diffusion/workflows/anatflow_l/fslmerge".
# 180726-17:25:10,500 workflow INFO:
# 	 [Node] Outdated cache found for "anatflow_l.fslmerge".
# 180726-17:25:10,646 workflow INFO:
# 	 [Node] Running "fslmerge" ("nipype.interfaces.fsl.utils.Merge"), a CommandLine Interface with command:
# fslmerge -t /Volumes/iang/active/BABIES/BABIES_diffusion/subjsDir/Newborn/1042-L-T2/bud.nii.gz /Volumes/iang/active/BABIES/BABIES_diffusion/workflows/anatflow_l/fslroi/mapflow/_fslroi0/DTI_pe1_roi.nii.gz /Volumes/iang/active/BABIES/BABIES_diffusion/workflows/anatflow_l/fslroi/mapflow/_fslroi1/DTI_pe0_ms103_roi.nii.gz
# 180726-17:25:12,427 workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 0 jobs ready. Free memory (GB): 28.60/28.80, Free processors: 0/1.
#                      Currently running:
#                        * anatflow_l.fslmerge
# 180726-17:25:12,419 workflow INFO:
# 	 [Node] Finished "anatflow_l.fslmerge".
# 180726-17:25:14,428 workflow INFO:
# 	 [Job 1] Completed (anatflow_l.fslmerge).
# 180726-17:25:14,431 workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 28.80/28.80, Free processors: 1/1.
# 180726-17:25:14,538 workflow INFO:
# 	 [Node] Outdated cache found for "anatflow_l.topup".
# 180726-17:25:14,540 workflow INFO:
# 	 [Node] Setting-up "anatflow_l.topup" in "/Volumes/iang/active/BABIES/BABIES_diffusion/workflows/anatflow_l/topup".
# 180726-17:25:14,546 workflow INFO:
# 	 [Node] Outdated cache found for "anatflow_l.topup".
# 180726-17:25:14,829 workflow INFO:
# 	 [Node] Running "topup" ("nipype.interfaces.fsl.epi.TOPUP"), a CommandLine Interface with command:
# topup --config=b02b0.cnf --datain=/Volumes/iang/active/BABIES/BABIES_diffusion/subjsDir/acq_params.txt --imain=/Volumes/iang/active/BABIES/BABIES_diffusion/subjsDir/Newborn/1042-L-T2/bud.nii.gz --out=/Volumes/iang/active/BABIES/BABIES_diffusion/subjsDir/Newborn/1042-L-T2/DTI_topup --iout=bud_corrected.nii.gz --fout=bud_field.nii.gz --jacout=jac --logout=bud_topup.log --rbmout=xfm --dfout=warpfield
# 180726-17:25:16,429 workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 0 jobs ready. Free memory (GB): 28.60/28.80, Free processors: 0/1.
#                      Currently running:
#                        * anatflow_l.topup
# 180726-17:29:13,442 workflow INFO:
# 	 [Node] Finished "anatflow_l.topup".
# 180726-17:29:14,691 workflow INFO:
# 	 [Job 2] Completed (anatflow_l.topup).
# 180726-17:29:14,693 workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 0 jobs ready. Free memory (GB): 28.80/28.80, Free processors: 1/1.
# 180726-17:29:17,171 workflow INFO:
# 	 Generated workflow graph: /Volumes/iang/active/BABIES/BABIES_diffusion/workflows/anatflow_l/graph.png (graph2use=flat, simple_form=True).
# 180726-17:29:17,193 workflow INFO:
# 	 Workflow anatflow_l settings: ['check', 'execution', 'logging', 'monitoring']
# 180726-17:29:17,284 workflow INFO:
# 	 Running in parallel.
# 180726-17:29:17,287 workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 28.80/28.80, Free processors: 1/1.
# 180726-17:29:19,287 workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 2 jobs ready. Free memory (GB): 28.80/28.80, Free processors: 1/1.
# 180726-17:29:19,341 workflow INFO:
# 	 [Node] Outdated cache found for "_fslroi0".
# 180726-17:29:19,347 workflow INFO:
# 	 [Node] Setting-up "_fslroi0" in "/Volumes/iang/active/BABIES/BABIES_diffusion/workflows/anatflow_l/fslroi/mapflow/_fslroi0".
# 180726-17:29:19,355 workflow INFO:
# 	 [Node] Outdated cache found for "_fslroi0".
# 180726-17:29:19,535 workflow INFO:
# 	 [Node] Running "_fslroi0" ("nipype.interfaces.fsl.utils.ExtractROI"), a CommandLine Interface with command:
# fslroi /Volumes/iang/active/BABIES/BABIES_diffusion/subjsDir/Newborn/1043-L-T2/raw/DTI_pe1.nii.gz /Volumes/iang/active/BABIES/BABIES_diffusion/scripts/DTI_pe1_roi.nii.gz 0 1
# 180726-17:29:20,852 workflow INFO:
# 	 [Node] Finished "_fslroi0".
# 180726-17:29:21,286 workflow INFO:
# 	 [Job 3] Completed (_fslroi0).
# 180726-17:29:21,288 workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 28.80/28.80, Free processors: 1/1.
# 180726-17:29:21,344 workflow INFO:
# 	 [Node] Outdated cache found for "_fslroi1".
# 180726-17:29:21,346 workflow INFO:
# 	 [Node] Setting-up "_fslroi1" in "/Volumes/iang/active/BABIES/BABIES_diffusion/workflows/anatflow_l/fslroi/mapflow/_fslroi1".
# 180726-17:29:21,352 workflow INFO:
# 	 [Node] Outdated cache found for "_fslroi1".
# 180726-17:29:21,466 workflow INFO:
# 	 [Node] Running "_fslroi1" ("nipype.interfaces.fsl.utils.ExtractROI"), a CommandLine Interface with command:
# fslroi /Volumes/iang/active/BABIES/BABIES_diffusion/subjsDir/Newborn/1043-L-T2/raw/DTI_pe0_ms103.nii.gz /Volumes/iang/active/BABIES/BABIES_diffusion/scripts/DTI_pe0_ms103_roi.nii.gz 0 1
# 180726-17:29:23,287 workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 0 jobs ready. Free memory (GB): 28.60/28.80, Free processors: 0/1.
#                      Currently running:
#                        * _fslroi1
# 180726-17:29:35,445 workflow INFO:
# 	 [Node] Finished "_fslroi1".
# 180726-17:29:37,293 workflow INFO:
# 	 [Job 4] Completed (_fslroi1).
# 180726-17:29:37,295 workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 28.80/28.80, Free processors: 1/1.
# 180726-17:29:37,351 workflow INFO:
# 	 [Node] Outdated cache found for "anatflow_l.fslroi".
# 180726-17:29:37,354 workflow INFO:
# 	 [Node] Setting-up "anatflow_l.fslroi" in "/Volumes/iang/active/BABIES/BABIES_diffusion/workflows/anatflow_l/fslroi".
# 180726-17:29:37,360 workflow INFO:
# 	 [Node] Outdated cache found for "anatflow_l.fslroi".
# 180726-17:29:37,408 workflow INFO:
# 	 [Node] Setting-up "_fslroi0" in "/Volumes/iang/active/BABIES/BABIES_diffusion/workflows/anatflow_l/fslroi/mapflow/_fslroi0".
# 180726-17:29:37,508 workflow INFO:
# 	 [Node] Cached "_fslroi0" - collecting precomputed outputs
# 180726-17:29:37,513 workflow INFO:
# 	 [Node] "_fslroi0" found cached.
# 180726-17:29:37,518 workflow INFO:
# 	 [Node] Setting-up "_fslroi1" in "/Volumes/iang/active/BABIES/BABIES_diffusion/workflows/anatflow_l/fslroi/mapflow/_fslroi1".
# 180726-17:29:37,574 workflow INFO:
# 	 [Node] Cached "_fslroi1" - collecting precomputed outputs
# 180726-17:29:37,578 workflow INFO:
# 	 [Node] "_fslroi1" found cached.
# 180726-17:29:37,637 workflow INFO:
# 	 [Node] Finished "anatflow_l.fslroi".
# 180726-17:29:39,296 workflow INFO:
# 	 [Job 0] Completed (anatflow_l.fslroi).
# 180726-17:29:39,298 workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 28.80/28.80, Free processors: 1/1.
# 180726-17:29:39,360 workflow INFO:
# 	 [Node] Outdated cache found for "anatflow_l.fslmerge".
# 180726-17:29:39,363 workflow INFO:
# 	 [Node] Setting-up "anatflow_l.fslmerge" in "/Volumes/iang/active/BABIES/BABIES_diffusion/workflows/anatflow_l/fslmerge".
# 180726-17:29:39,368 workflow INFO:
# 	 [Node] Outdated cache found for "anatflow_l.fslmerge".
# 180726-17:29:39,484 workflow INFO:
# 	 [Node] Running "fslmerge" ("nipype.interfaces.fsl.utils.Merge"), a CommandLine Interface with command:
# fslmerge -t /Volumes/iang/active/BABIES/BABIES_diffusion/subjsDir/Newborn/1043-L-T2/bud.nii.gz /Volumes/iang/active/BABIES/BABIES_diffusion/workflows/anatflow_l/fslroi/mapflow/_fslroi0/DTI_pe1_roi.nii.gz /Volumes/iang/active/BABIES/BABIES_diffusion/workflows/anatflow_l/fslroi/mapflow/_fslroi1/DTI_pe0_ms103_roi.nii.gz
# 180726-17:29:40,691 workflow INFO:
# 	 [Node] Finished "anatflow_l.fslmerge".
# 180726-17:29:41,300 workflow INFO:
# 	 [Job 1] Completed (anatflow_l.fslmerge).
# 180726-17:29:41,302 workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 28.80/28.80, Free processors: 1/1.
# 180726-17:29:41,368 workflow INFO:
# 	 [Node] Outdated cache found for "anatflow_l.topup".
# 180726-17:29:41,371 workflow INFO:
# 	 [Node] Setting-up "anatflow_l.topup" in "/Volumes/iang/active/BABIES/BABIES_diffusion/workflows/anatflow_l/topup".
# 180726-17:29:41,377 workflow INFO:
# 	 [Node] Outdated cache found for "anatflow_l.topup".
# 180726-17:29:41,551 workflow INFO:
# 	 [Node] Running "topup" ("nipype.interfaces.fsl.epi.TOPUP"), a CommandLine Interface with command:
# topup --config=b02b0.cnf --datain=/Volumes/iang/active/BABIES/BABIES_diffusion/subjsDir/acq_params.txt --imain=/Volumes/iang/active/BABIES/BABIES_diffusion/subjsDir/Newborn/1043-L-T2/bud.nii.gz --out=/Volumes/iang/active/BABIES/BABIES_diffusion/subjsDir/Newborn/1043-L-T2/DTI_topup --iout=bud_corrected.nii.gz --fout=bud_field.nii.gz --jacout=jac --logout=bud_topup.log --rbmout=xfm --dfout=warpfield
# 180726-17:29:43,301 workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 0 jobs ready. Free memory (GB): 28.60/28.80, Free processors: 0/1.
#                      Currently running:
#                        * anatflow_l.topup
# 180726-17:33:40,562 workflow INFO:
# 	 [Node] Finished "anatflow_l.topup".
# 180726-17:33:41,547 workflow INFO:
# 	 [Job 2] Completed (anatflow_l.topup).
# 180726-17:33:41,549 workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 0 jobs ready. Free memory (GB): 28.80/28.80, Free processors: 1/1.
# 180726-17:33:44,36 workflow INFO:
# 	 Generated workflow graph: /Volumes/iang/active/BABIES/BABIES_diffusion/workflows/anatflow_l/graph.png (graph2use=flat, simple_form=True).
# 180726-17:33:44,59 workflow INFO:
# 	 Workflow anatflow_l settings: ['check', 'execution', 'logging', 'monitoring']
# 180726-17:33:44,146 workflow INFO:
# 	 Running in parallel.
# 180726-17:33:44,150 workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 28.80/28.80, Free processors: 1/1.
# 180726-17:33:46,152 workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 2 jobs ready. Free memory (GB): 28.80/28.80, Free processors: 1/1.
# 180726-17:33:46,209 workflow INFO:
# 	 [Node] Outdated cache found for "_fslroi0".
# 180726-17:33:46,213 workflow INFO:
# 	 [Node] Setting-up "_fslroi0" in "/Volumes/iang/active/BABIES/BABIES_diffusion/workflows/anatflow_l/fslroi/mapflow/_fslroi0".
# 180726-17:33:46,221 workflow INFO:
# 	 [Node] Outdated cache found for "_fslroi0".
# 180726-17:33:46,634 workflow INFO:
# 	 [Node] Running "_fslroi0" ("nipype.interfaces.fsl.utils.ExtractROI"), a CommandLine Interface with command:
# fslroi /Volumes/iang/active/BABIES/BABIES_diffusion/subjsDir/Newborn/1053-L-T2/raw/DTI_pe1.nii.gz /Volumes/iang/active/BABIES/BABIES_diffusion/scripts/DTI_pe1_roi.nii.gz 0 1
# 180726-17:33:48,152 workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 1 jobs ready. Free memory (GB): 28.60/28.80, Free processors: 0/1.
#                      Currently running:
#                        * _fslroi0
# 180726-17:33:48,450 workflow INFO:
# 	 [Node] Finished "_fslroi0".
# 180726-17:33:50,153 workflow INFO:
# 	 [Job 3] Completed (_fslroi0).
# 180726-17:33:50,155 workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 28.80/28.80, Free processors: 1/1.
# 180726-17:33:50,210 workflow INFO:
# 	 [Node] Outdated cache found for "_fslroi1".
# 180726-17:33:50,212 workflow INFO:
# 	 [Node] Setting-up "_fslroi1" in "/Volumes/iang/active/BABIES/BABIES_diffusion/workflows/anatflow_l/fslroi/mapflow/_fslroi1".
# 180726-17:33:50,217 workflow INFO:
# 	 [Node] Outdated cache found for "_fslroi1".
# 180726-17:33:50,395 workflow INFO:
# 	 [Node] Running "_fslroi1" ("nipype.interfaces.fsl.utils.ExtractROI"), a CommandLine Interface with command:
# fslroi /Volumes/iang/active/BABIES/BABIES_diffusion/subjsDir/Newborn/1053-L-T2/raw/DTI_pe0_ms103.nii.gz /Volumes/iang/active/BABIES/BABIES_diffusion/scripts/DTI_pe0_ms103_roi.nii.gz 0 1
# 180726-17:33:52,154 workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 0 jobs ready. Free memory (GB): 28.60/28.80, Free processors: 0/1.
#                      Currently running:
#                        * _fslroi1
# 180726-17:34:02,446 workflow INFO:
# 	 [Node] Finished "_fslroi1".
# 180726-17:34:04,163 workflow INFO:
# 	 [Job 4] Completed (_fslroi1).
# 180726-17:34:04,164 workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 28.80/28.80, Free processors: 1/1.
# 180726-17:34:04,251 workflow INFO:
# 	 [Node] Outdated cache found for "anatflow_l.fslroi".
# 180726-17:34:04,253 workflow INFO:
# 	 [Node] Setting-up "anatflow_l.fslroi" in "/Volumes/iang/active/BABIES/BABIES_diffusion/workflows/anatflow_l/fslroi".
# 180726-17:34:04,260 workflow INFO:
# 	 [Node] Outdated cache found for "anatflow_l.fslroi".
# 180726-17:34:04,308 workflow INFO:
# 	 [Node] Setting-up "_fslroi0" in "/Volumes/iang/active/BABIES/BABIES_diffusion/workflows/anatflow_l/fslroi/mapflow/_fslroi0".
# 180726-17:34:04,410 workflow INFO:
# 	 [Node] Cached "_fslroi0" - collecting precomputed outputs
# 180726-17:34:04,414 workflow INFO:
# 	 [Node] "_fslroi0" found cached.
# 180726-17:34:04,418 workflow INFO:
# 	 [Node] Setting-up "_fslroi1" in "/Volumes/iang/active/BABIES/BABIES_diffusion/workflows/anatflow_l/fslroi/mapflow/_fslroi1".
# 180726-17:34:04,494 workflow INFO:
# 	 [Node] Cached "_fslroi1" - collecting precomputed outputs
# 180726-17:34:04,498 workflow INFO:
# 	 [Node] "_fslroi1" found cached.
# 180726-17:34:04,562 workflow INFO:
# 	 [Node] Finished "anatflow_l.fslroi".
# 180726-17:34:06,166 workflow INFO:
# 	 [Job 0] Completed (anatflow_l.fslroi).
# 180726-17:34:06,168 workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 28.80/28.80, Free processors: 1/1.
# 180726-17:34:06,233 workflow INFO:
# 	 [Node] Outdated cache found for "anatflow_l.fslmerge".
# 180726-17:34:06,235 workflow INFO:
# 	 [Node] Setting-up "anatflow_l.fslmerge" in "/Volumes/iang/active/BABIES/BABIES_diffusion/workflows/anatflow_l/fslmerge".
# 180726-17:34:06,241 workflow INFO:
# 	 [Node] Outdated cache found for "anatflow_l.fslmerge".
# 180726-17:34:06,569 workflow INFO:
# 	 [Node] Running "fslmerge" ("nipype.interfaces.fsl.utils.Merge"), a CommandLine Interface with command:
# fslmerge -t /Volumes/iang/active/BABIES/BABIES_diffusion/subjsDir/Newborn/1053-L-T2/bud.nii.gz /Volumes/iang/active/BABIES/BABIES_diffusion/workflows/anatflow_l/fslroi/mapflow/_fslroi0/DTI_pe1_roi.nii.gz /Volumes/iang/active/BABIES/BABIES_diffusion/workflows/anatflow_l/fslroi/mapflow/_fslroi1/DTI_pe0_ms103_roi.nii.gz
# 180726-17:34:07,861 workflow INFO:
# 	 [Node] Finished "anatflow_l.fslmerge".
# 180726-17:34:08,168 workflow INFO:
# 	 [Job 1] Completed (anatflow_l.fslmerge).
# 180726-17:34:08,170 workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 28.80/28.80, Free processors: 1/1.
# 180726-17:34:08,233 workflow INFO:
# 	 [Node] Outdated cache found for "anatflow_l.topup".
# 180726-17:34:08,235 workflow INFO:
# 	 [Node] Setting-up "anatflow_l.topup" in "/Volumes/iang/active/BABIES/BABIES_diffusion/workflows/anatflow_l/topup".
# 180726-17:34:08,240 workflow INFO:
# 	 [Node] Outdated cache found for "anatflow_l.topup".
# 180726-17:34:08,545 workflow INFO:
# 	 [Node] Running "topup" ("nipype.interfaces.fsl.epi.TOPUP"), a CommandLine Interface with command:
# topup --config=b02b0.cnf --datain=/Volumes/iang/active/BABIES/BABIES_diffusion/subjsDir/acq_params.txt --imain=/Volumes/iang/active/BABIES/BABIES_diffusion/subjsDir/Newborn/1053-L-T2/bud.nii.gz --out=/Volumes/iang/active/BABIES/BABIES_diffusion/subjsDir/Newborn/1053-L-T2/DTI_topup --iout=bud_corrected.nii.gz --fout=bud_field.nii.gz --jacout=jac --logout=bud_topup.log --rbmout=xfm --dfout=warpfield
# 180726-17:34:10,174 workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 0 jobs ready. Free memory (GB): 28.60/28.80, Free processors: 0/1.
#                      Currently running:
#                        * anatflow_l.topup
# 180726-17:38:06,114 workflow INFO:
# 	 [Node] Finished "anatflow_l.topup".
# 180726-17:38:06,435 workflow INFO:
# 	 [Job 2] Completed (anatflow_l.topup).
# 180726-17:38:06,437 workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 0 jobs ready. Free memory (GB): 28.80/28.80, Free processors: 1/1.
# 180726-17:38:08,915 workflow INFO:
# 	 Generated workflow graph: /Volumes/iang/active/BABIES/BABIES_diffusion/workflows/anatflow_l/graph.png (graph2use=flat, simple_form=True).
# 180726-17:38:08,937 workflow INFO:
# 	 Workflow anatflow_l settings: ['check', 'execution', 'logging', 'monitoring']
# 180726-17:38:09,27 workflow INFO:
# 	 Running in parallel.
# 180726-17:38:09,31 workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 28.80/28.80, Free processors: 1/1.
# 180726-17:38:11,35 workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 2 jobs ready. Free memory (GB): 28.80/28.80, Free processors: 1/1.
# 180726-17:38:11,106 workflow INFO:
# 	 [Node] Outdated cache found for "_fslroi0".
# 180726-17:38:11,110 workflow INFO:
# 	 [Node] Setting-up "_fslroi0" in "/Volumes/iang/active/BABIES/BABIES_diffusion/workflows/anatflow_l/fslroi/mapflow/_fslroi0".
# 180726-17:38:11,118 workflow INFO:
# 	 [Node] Outdated cache found for "_fslroi0".
# 180726-17:38:11,262 workflow INFO:
# 	 [Node] Running "_fslroi0" ("nipype.interfaces.fsl.utils.ExtractROI"), a CommandLine Interface with command:
# fslroi /Volumes/iang/active/BABIES/BABIES_diffusion/subjsDir/Newborn/1057-L-T2/raw/DTI_pe1.nii.gz /Volumes/iang/active/BABIES/BABIES_diffusion/scripts/DTI_pe1_roi.nii.gz 0 1
# 180726-17:38:12,472 workflow INFO:
# 	 [Node] Finished "_fslroi0".
# 180726-17:38:13,35 workflow INFO:
# 	 [Job 3] Completed (_fslroi0).
# 180726-17:38:13,37 workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 28.80/28.80, Free processors: 1/1.
# 180726-17:38:13,90 workflow INFO:
# 	 [Node] Outdated cache found for "_fslroi1".
# 180726-17:38:13,92 workflow INFO:
# 	 [Node] Setting-up "_fslroi1" in "/Volumes/iang/active/BABIES/BABIES_diffusion/workflows/anatflow_l/fslroi/mapflow/_fslroi1".
# 180726-17:38:13,98 workflow INFO:
# 	 [Node] Outdated cache found for "_fslroi1".
# 180726-17:38:13,261 workflow INFO:
# 	 [Node] Running "_fslroi1" ("nipype.interfaces.fsl.utils.ExtractROI"), a CommandLine Interface with command:
# fslroi /Volumes/iang/active/BABIES/BABIES_diffusion/subjsDir/Newborn/1057-L-T2/raw/DTI_pe0_ms103.nii.gz /Volumes/iang/active/BABIES/BABIES_diffusion/scripts/DTI_pe0_ms103_roi.nii.gz 0 1
# 180726-17:38:15,37 workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 0 jobs ready. Free memory (GB): 28.60/28.80, Free processors: 0/1.
#                      Currently running:
#                        * _fslroi1
# 180726-17:38:24,313 workflow INFO:
# 	 [Node] Finished "_fslroi1".
# 180726-17:38:25,48 workflow INFO:
# 	 [Job 4] Completed (_fslroi1).
# 180726-17:38:25,50 workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 28.80/28.80, Free processors: 1/1.
# 180726-17:38:25,130 workflow INFO:
# 	 [Node] Outdated cache found for "anatflow_l.fslroi".
# 180726-17:38:25,133 workflow INFO:
# 	 [Node] Setting-up "anatflow_l.fslroi" in "/Volumes/iang/active/BABIES/BABIES_diffusion/workflows/anatflow_l/fslroi".
# 180726-17:38:25,139 workflow INFO:
# 	 [Node] Outdated cache found for "anatflow_l.fslroi".
# 180726-17:38:25,194 workflow INFO:
# 	 [Node] Setting-up "_fslroi0" in "/Volumes/iang/active/BABIES/BABIES_diffusion/workflows/anatflow_l/fslroi/mapflow/_fslroi0".
# 180726-17:38:25,286 workflow INFO:
# 	 [Node] Cached "_fslroi0" - collecting precomputed outputs
# 180726-17:38:25,290 workflow INFO:
# 	 [Node] "_fslroi0" found cached.
# 180726-17:38:25,294 workflow INFO:
# 	 [Node] Setting-up "_fslroi1" in "/Volumes/iang/active/BABIES/BABIES_diffusion/workflows/anatflow_l/fslroi/mapflow/_fslroi1".
# 180726-17:38:25,346 workflow INFO:
# 	 [Node] Cached "_fslroi1" - collecting precomputed outputs
# 180726-17:38:25,351 workflow INFO:
# 	 [Node] "_fslroi1" found cached.
# 180726-17:38:25,409 workflow INFO:
# 	 [Node] Finished "anatflow_l.fslroi".
# 180726-17:38:27,49 workflow INFO:
# 	 [Job 0] Completed (anatflow_l.fslroi).
# 180726-17:38:27,51 workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 28.80/28.80, Free processors: 1/1.
# 180726-17:38:27,123 workflow INFO:
# 	 [Node] Outdated cache found for "anatflow_l.fslmerge".
# 180726-17:38:27,126 workflow INFO:
# 	 [Node] Setting-up "anatflow_l.fslmerge" in "/Volumes/iang/active/BABIES/BABIES_diffusion/workflows/anatflow_l/fslmerge".
# 180726-17:38:27,130 workflow INFO:
# 	 [Node] Outdated cache found for "anatflow_l.fslmerge".
# 180726-17:38:27,235 workflow INFO:
# 	 [Node] Running "fslmerge" ("nipype.interfaces.fsl.utils.Merge"), a CommandLine Interface with command:
# fslmerge -t /Volumes/iang/active/BABIES/BABIES_diffusion/subjsDir/Newborn/1057-L-T2/bud.nii.gz /Volumes/iang/active/BABIES/BABIES_diffusion/workflows/anatflow_l/fslroi/mapflow/_fslroi0/DTI_pe1_roi.nii.gz /Volumes/iang/active/BABIES/BABIES_diffusion/workflows/anatflow_l/fslroi/mapflow/_fslroi1/DTI_pe0_ms103_roi.nii.gz
# 180726-17:38:28,779 workflow INFO:
# 	 [Node] Finished "anatflow_l.fslmerge".
# 180726-17:38:29,49 workflow INFO:
# 	 [Job 1] Completed (anatflow_l.fslmerge).
# 180726-17:38:29,52 workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 28.80/28.80, Free processors: 1/1.
# 180726-17:38:29,114 workflow INFO:
# 	 [Node] Outdated cache found for "anatflow_l.topup".
# 180726-17:38:29,117 workflow INFO:
# 	 [Node] Setting-up "anatflow_l.topup" in "/Volumes/iang/active/BABIES/BABIES_diffusion/workflows/anatflow_l/topup".
# 180726-17:38:29,122 workflow INFO:
# 	 [Node] Outdated cache found for "anatflow_l.topup".
# 180726-17:38:29,628 workflow INFO:
# 	 [Node] Running "topup" ("nipype.interfaces.fsl.epi.TOPUP"), a CommandLine Interface with command:
# topup --config=b02b0.cnf --datain=/Volumes/iang/active/BABIES/BABIES_diffusion/subjsDir/acq_params.txt --imain=/Volumes/iang/active/BABIES/BABIES_diffusion/subjsDir/Newborn/1057-L-T2/bud.nii.gz --out=/Volumes/iang/active/BABIES/BABIES_diffusion/subjsDir/Newborn/1057-L-T2/DTI_topup --iout=bud_corrected.nii.gz --fout=bud_field.nii.gz --jacout=jac --logout=bud_topup.log --rbmout=xfm --dfout=warpfield
# 180726-17:38:31,50 workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 0 jobs ready. Free memory (GB): 28.60/28.80, Free processors: 0/1.
#                      Currently running:
#                        * anatflow_l.topup
# 180726-17:42:30,243 workflow INFO:
# 	 [Node] Finished "anatflow_l.topup".
# 180726-17:42:31,334 workflow INFO:
# 	 [Job 2] Completed (anatflow_l.topup).
# 180726-17:42:31,337 workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 0 jobs ready. Free memory (GB): 28.80/28.80, Free processors: 1/1.

# %%
for sub in ready_to_run:
    dest = destfp + '/' + sub + '/'
    pe1_nii = destfp + '/' + sub + '/raw/DTI_pe1.nii.gz'
    pe1_bvec = destfp + '/' + sub + '/raw/DTI_pe1.bvec'
    pe1_bval = destfp + '/' + sub + '/raw/DTI_pe1.bval'
    pe0_nii = destfp + '/' + sub + '/raw/DTI_pe0_ms103.nii.gz'
    pe0_bvec = destfp + '/' + sub + '/raw/DTI_pe0_ms103.bvec'
    pe0_bval = destfp + '/' + sub + '/raw/DTI_pe0_ms103.bval'
    dest = destfp + '/' + sub + '/'
    applytopup = pe.Node(interface = fsl.ApplyTOPUP(encoding_file = params,
                                                    in_files = [pe0_nii],
                                                    method = 'jac',
                                                    in_topup_fieldcoef = dest + 'DTI_topup_fieldcoef.nii.gz',
                                                    in_topup_movpar = dest + 'DTI_topup_movpar.txt',
                                                    in_index = [1],
                                                    out_corrected = dest + 'DTI_pe0_corrected.nii.gz',
                                                    output_type = "NIFTI_GZ"),
                            name = 'applytopup')
    #applytopup.outputs.out_corrected = dest + 'DTI_pe0_corrected.nii.gz'
    bet = pe.Node(interface = fsl.BET(mask = True, out_file = dest + 'DTI_pe0_corrected_stripped.nii.gz' ),
                  name = 'bet')
    init_proc_l=pe.Workflow(name="init_proc_l")
    init_proc_l.connect([(applytopup, bet, [('out_corrected', 'in_file')])
                       ])
    init_proc_l.base_dir = workflow_dir
    init_proc_l.write_graph(graph2use = 'flat')
    init_proc_l.run('MultiProc', plugin_args={'n_procs': 1})
# Out:
# 180726-18:38:32,293 workflow INFO:
# 	 Generated workflow graph: /Volumes/iang/active/BABIES/BABIES_diffusion/workflows/init_proc_l/graph.png (graph2use=flat, simple_form=True).
# 180726-18:38:32,320 workflow INFO:
# 	 Workflow init_proc_l settings: ['check', 'execution', 'logging', 'monitoring']
# 180726-18:38:32,431 workflow INFO:
# 	 Running in parallel.
# 180726-18:38:32,434 workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 28.80/28.80, Free processors: 1/1.
# 180726-18:38:32,531 workflow INFO:
# 	 [Node] Setting-up "init_proc_l.applytopup" in "/Volumes/iang/active/BABIES/BABIES_diffusion/workflows/init_proc_l/applytopup".
# 180726-18:38:32,767 workflow INFO:
# 	 [Node] Running "applytopup" ("nipype.interfaces.fsl.epi.ApplyTOPUP"), a CommandLine Interface with command:
# applytopup --datain=/Volumes/iang/active/BABIES/BABIES_diffusion/subjsDir/acq_params.txt --imain=/Volumes/iang/active/BABIES/BABIES_diffusion/subjsDir/Newborn/1005-L-T2/raw/DTI_pe0_ms103.nii.gz --inindex=1 --topup=/Volumes/iang/active/BABIES/BABIES_diffusion/workflows/init_proc_l/applytopup/DTI_topup --method=jac --out=/Volumes/iang/active/BABIES/BABIES_diffusion/subjsDir/Newborn/1005-L-T2/DTI_pe0_corrected.nii.gz
# 180726-18:38:34,434 workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 0 jobs ready. Free memory (GB): 28.60/28.80, Free processors: 0/1.
#                      Currently running:
#                        * init_proc_l.applytopup
# 180726-18:39:58,255 workflow INFO:
# 	 [Node] Finished "init_proc_l.applytopup".
# 180726-18:39:58,513 workflow INFO:
# 	 [Job 0] Completed (init_proc_l.applytopup).
# 180726-18:39:58,516 workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 28.80/28.80, Free processors: 1/1.
# 180726-18:39:58,654 workflow INFO:
# 	 [Node] Outdated cache found for "init_proc_l.bet".
# 180726-18:39:58,656 workflow INFO:
# 	 [Node] Setting-up "init_proc_l.bet" in "/Volumes/iang/active/BABIES/BABIES_diffusion/workflows/init_proc_l/bet".
# 180726-18:39:58,662 workflow INFO:
# 	 [Node] Outdated cache found for "init_proc_l.bet".
# 180726-18:39:58,933 workflow INFO:
# 	 [Node] Running "bet" ("nipype.interfaces.fsl.preprocess.BET"), a CommandLine Interface with command:
# bet /Volumes/iang/active/BABIES/BABIES_diffusion/subjsDir/Newborn/1005-L-T2/DTI_pe0_corrected.nii.gz /Volumes/iang/active/BABIES/BABIES_diffusion/subjsDir/Newborn/1005-L-T2/DTI_pe0_corrected_stripped.nii.gz -m
# 180726-18:40:00,518 workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 0 jobs ready. Free memory (GB): 28.60/28.80, Free processors: 0/1.
#                      Currently running:
#                        * init_proc_l.bet
# 180726-18:40:00,734 workflow INFO:
# 	 [Node] Finished "init_proc_l.bet".
# 180726-18:40:02,518 workflow INFO:
# 	 [Job 1] Completed (init_proc_l.bet).
# 180726-18:40:02,520 workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 0 jobs ready. Free memory (GB): 28.80/28.80, Free processors: 1/1.
# 180726-18:40:04,995 workflow INFO:
# 	 Generated workflow graph: /Volumes/iang/active/BABIES/BABIES_diffusion/workflows/init_proc_l/graph.png (graph2use=flat, simple_form=True).
# 180726-18:40:05,21 workflow INFO:
# 	 Workflow init_proc_l settings: ['check', 'execution', 'logging', 'monitoring']
# 180726-18:40:05,110 workflow INFO:
# 	 Running in parallel.
# 180726-18:40:05,114 workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 28.80/28.80, Free processors: 1/1.
# 180726-18:40:05,204 workflow INFO:
# 	 [Node] Outdated cache found for "init_proc_l.applytopup".
# 180726-18:40:05,210 workflow INFO:
# 	 [Node] Setting-up "init_proc_l.applytopup" in "/Volumes/iang/active/BABIES/BABIES_diffusion/workflows/init_proc_l/applytopup".
# 180726-18:40:05,218 workflow INFO:
# 	 [Node] Outdated cache found for "init_proc_l.applytopup".
# 180726-18:40:05,440 workflow INFO:
# 	 [Node] Running "applytopup" ("nipype.interfaces.fsl.epi.ApplyTOPUP"), a CommandLine Interface with command:
# applytopup --datain=/Volumes/iang/active/BABIES/BABIES_diffusion/subjsDir/acq_params.txt --imain=/Volumes/iang/active/BABIES/BABIES_diffusion/subjsDir/Newborn/1011-L-T2/raw/DTI_pe0_ms103.nii.gz --inindex=1 --topup=/Volumes/iang/active/BABIES/BABIES_diffusion/workflows/init_proc_l/applytopup/DTI_topup --method=jac --out=/Volumes/iang/active/BABIES/BABIES_diffusion/subjsDir/Newborn/1011-L-T2/DTI_pe0_corrected.nii.gz
# 180726-18:40:07,115 workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 0 jobs ready. Free memory (GB): 28.60/28.80, Free processors: 0/1.
#                      Currently running:
#                        * init_proc_l.applytopup
# 180726-18:40:17,703 workflow INFO:
# 	 [Node] Finished "init_proc_l.applytopup".
# 180726-18:40:19,129 workflow INFO:
# 	 [Job 0] Completed (init_proc_l.applytopup).
# 180726-18:40:19,131 workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 28.80/28.80, Free processors: 1/1.
# 180726-18:40:19,192 workflow INFO:
# 	 [Node] Outdated cache found for "init_proc_l.bet".
# 180726-18:40:19,194 workflow INFO:
# 	 [Node] Setting-up "init_proc_l.bet" in "/Volumes/iang/active/BABIES/BABIES_diffusion/workflows/init_proc_l/bet".
# 180726-18:40:19,200 workflow INFO:
# 	 [Node] Outdated cache found for "init_proc_l.bet".
# 180726-18:40:19,432 workflow INFO:
# 	 [Node] Running "bet" ("nipype.interfaces.fsl.preprocess.BET"), a CommandLine Interface with command:
# bet /Volumes/iang/active/BABIES/BABIES_diffusion/subjsDir/Newborn/1011-L-T2/DTI_pe0_corrected.nii.gz /Volumes/iang/active/BABIES/BABIES_diffusion/subjsDir/Newborn/1011-L-T2/DTI_pe0_corrected_stripped.nii.gz -m
# 180726-18:40:21,130 workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 0 jobs ready. Free memory (GB): 28.60/28.80, Free processors: 0/1.
#                      Currently running:
#                        * init_proc_l.bet
# 180726-18:40:21,397 workflow INFO:
# 	 [Node] Finished "init_proc_l.bet".
# 180726-18:40:23,134 workflow INFO:
# 	 [Job 1] Completed (init_proc_l.bet).
# 180726-18:40:23,137 workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 0 jobs ready. Free memory (GB): 28.80/28.80, Free processors: 1/1.
# 180726-18:40:28,347 workflow INFO:
# 	 Generated workflow graph: /Volumes/iang/active/BABIES/BABIES_diffusion/workflows/init_proc_l/graph.png (graph2use=flat, simple_form=True).
# 180726-18:40:28,388 workflow INFO:
# 	 Workflow init_proc_l settings: ['check', 'execution', 'logging', 'monitoring']
# 180726-18:40:28,558 workflow INFO:
# 	 Running in parallel.
# 180726-18:40:28,562 workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 28.80/28.80, Free processors: 1/1.
# 180726-18:40:28,671 workflow INFO:
# 	 [Node] Outdated cache found for "init_proc_l.applytopup".
# 180726-18:40:28,676 workflow INFO:
# 	 [Node] Setting-up "init_proc_l.applytopup" in "/Volumes/iang/active/BABIES/BABIES_diffusion/workflows/init_proc_l/applytopup".
# 180726-18:40:28,684 workflow INFO:
# 	 [Node] Outdated cache found for "init_proc_l.applytopup".
# 180726-18:40:28,933 workflow INFO:
# 	 [Node] Running "applytopup" ("nipype.interfaces.fsl.epi.ApplyTOPUP"), a CommandLine Interface with command:
# applytopup --datain=/Volumes/iang/active/BABIES/BABIES_diffusion/subjsDir/acq_params.txt --imain=/Volumes/iang/active/BABIES/BABIES_diffusion/subjsDir/Newborn/1028-L-T2/raw/DTI_pe0_ms103.nii.gz --inindex=1 --topup=/Volumes/iang/active/BABIES/BABIES_diffusion/workflows/init_proc_l/applytopup/DTI_topup --method=jac --out=/Volumes/iang/active/BABIES/BABIES_diffusion/subjsDir/Newborn/1028-L-T2/DTI_pe0_corrected.nii.gz
# 180726-18:40:30,562 workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 0 jobs ready. Free memory (GB): 28.60/28.80, Free processors: 0/1.
#                      Currently running:
#                        * init_proc_l.applytopup
# 180726-18:42:00,924 workflow INFO:
# 	 [Node] Finished "init_proc_l.applytopup".
# 180726-18:42:02,638 workflow INFO:
# 	 [Job 0] Completed (init_proc_l.applytopup).
# 180726-18:42:02,640 workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 28.80/28.80, Free processors: 1/1.
# 180726-18:42:02,977 workflow INFO:
# 	 [Node] Outdated cache found for "init_proc_l.bet".
# 180726-18:42:02,979 workflow INFO:
# 	 [Node] Setting-up "init_proc_l.bet" in "/Volumes/iang/active/BABIES/BABIES_diffusion/workflows/init_proc_l/bet".
# 180726-18:42:02,986 workflow INFO:
# 	 [Node] Outdated cache found for "init_proc_l.bet".
# 180726-18:42:03,487 workflow INFO:
# 	 [Node] Running "bet" ("nipype.interfaces.fsl.preprocess.BET"), a CommandLine Interface with command:
# bet /Volumes/iang/active/BABIES/BABIES_diffusion/subjsDir/Newborn/1028-L-T2/DTI_pe0_corrected.nii.gz /Volumes/iang/active/BABIES/BABIES_diffusion/subjsDir/Newborn/1028-L-T2/DTI_pe0_corrected_stripped.nii.gz -m
# 180726-18:42:04,638 workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 0 jobs ready. Free memory (GB): 28.60/28.80, Free processors: 0/1.
#                      Currently running:
#                        * init_proc_l.bet
# 180726-18:42:07,778 workflow INFO:
# 	 [Node] Finished "init_proc_l.bet".
# 180726-18:42:08,643 workflow INFO:
# 	 [Job 1] Completed (init_proc_l.bet).
# 180726-18:42:08,645 workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 0 jobs ready. Free memory (GB): 28.80/28.80, Free processors: 1/1.
# 180726-18:42:11,127 workflow INFO:
# 	 Generated workflow graph: /Volumes/iang/active/BABIES/BABIES_diffusion/workflows/init_proc_l/graph.png (graph2use=flat, simple_form=True).
# 180726-18:42:11,152 workflow INFO:
# 	 Workflow init_proc_l settings: ['check', 'execution', 'logging', 'monitoring']
# 180726-18:42:11,235 workflow INFO:
# 	 Running in parallel.
# 180726-18:42:11,238 workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 28.80/28.80, Free processors: 1/1.
# 180726-18:42:11,336 workflow INFO:
# 	 [Node] Outdated cache found for "init_proc_l.applytopup".
# 180726-18:42:11,342 workflow INFO:
# 	 [Node] Setting-up "init_proc_l.applytopup" in "/Volumes/iang/active/BABIES/BABIES_diffusion/workflows/init_proc_l/applytopup".
# 180726-18:42:11,351 workflow INFO:
# 	 [Node] Outdated cache found for "init_proc_l.applytopup".
# 180726-18:42:11,618 workflow INFO:
# 	 [Node] Running "applytopup" ("nipype.interfaces.fsl.epi.ApplyTOPUP"), a CommandLine Interface with command:
# applytopup --datain=/Volumes/iang/active/BABIES/BABIES_diffusion/subjsDir/acq_params.txt --imain=/Volumes/iang/active/BABIES/BABIES_diffusion/subjsDir/Newborn/1038-L-T2/raw/DTI_pe0_ms103.nii.gz --inindex=1 --topup=/Volumes/iang/active/BABIES/BABIES_diffusion/workflows/init_proc_l/applytopup/DTI_topup --method=jac --out=/Volumes/iang/active/BABIES/BABIES_diffusion/subjsDir/Newborn/1038-L-T2/DTI_pe0_corrected.nii.gz
# 180726-18:42:13,238 workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 0 jobs ready. Free memory (GB): 28.60/28.80, Free processors: 0/1.
#                      Currently running:
#                        * init_proc_l.applytopup
# 180726-18:42:57,142 workflow INFO:
# 	 [Node] Finished "init_proc_l.applytopup".
# 180726-18:42:57,257 workflow INFO:
# 	 [Job 0] Completed (init_proc_l.applytopup).
# 180726-18:42:57,259 workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 28.80/28.80, Free processors: 1/1.
# 180726-18:42:57,325 workflow INFO:
# 	 [Node] Outdated cache found for "init_proc_l.bet".
# 180726-18:42:57,327 workflow INFO:
# 	 [Node] Setting-up "init_proc_l.bet" in "/Volumes/iang/active/BABIES/BABIES_diffusion/workflows/init_proc_l/bet".
# 180726-18:42:57,333 workflow INFO:
# 	 [Node] Outdated cache found for "init_proc_l.bet".
# 180726-18:42:57,660 workflow INFO:
# 	 [Node] Running "bet" ("nipype.interfaces.fsl.preprocess.BET"), a CommandLine Interface with command:
# bet /Volumes/iang/active/BABIES/BABIES_diffusion/subjsDir/Newborn/1038-L-T2/DTI_pe0_corrected.nii.gz /Volumes/iang/active/BABIES/BABIES_diffusion/subjsDir/Newborn/1038-L-T2/DTI_pe0_corrected_stripped.nii.gz -m
# 180726-18:42:59,261 workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 0 jobs ready. Free memory (GB): 28.60/28.80, Free processors: 0/1.
#                      Currently running:
#                        * init_proc_l.bet
# 180726-18:42:59,432 workflow INFO:
# 	 [Node] Finished "init_proc_l.bet".
# 180726-18:43:01,263 workflow INFO:
# 	 [Job 1] Completed (init_proc_l.bet).
# 180726-18:43:01,265 workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 0 jobs ready. Free memory (GB): 28.80/28.80, Free processors: 1/1.
# 180726-18:43:04,389 workflow INFO:
# 	 Generated workflow graph: /Volumes/iang/active/BABIES/BABIES_diffusion/workflows/init_proc_l/graph.png (graph2use=flat, simple_form=True).
# 180726-18:43:04,417 workflow INFO:
# 	 Workflow init_proc_l settings: ['check', 'execution', 'logging', 'monitoring']
# 180726-18:43:04,556 workflow INFO:
# 	 Running in parallel.
# 180726-18:43:04,560 workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 28.80/28.80, Free processors: 1/1.
# 180726-18:43:04,666 workflow INFO:
# 	 [Node] Outdated cache found for "init_proc_l.applytopup".
# 180726-18:43:04,672 workflow INFO:
# 	 [Node] Setting-up "init_proc_l.applytopup" in "/Volumes/iang/active/BABIES/BABIES_diffusion/workflows/init_proc_l/applytopup".
# 180726-18:43:04,691 workflow INFO:
# 	 [Node] Outdated cache found for "init_proc_l.applytopup".
# 180726-18:43:05,371 workflow INFO:
# 	 [Node] Running "applytopup" ("nipype.interfaces.fsl.epi.ApplyTOPUP"), a CommandLine Interface with command:
# applytopup --datain=/Volumes/iang/active/BABIES/BABIES_diffusion/subjsDir/acq_params.txt --imain=/Volumes/iang/active/BABIES/BABIES_diffusion/subjsDir/Newborn/1042-L-T2/raw/DTI_pe0_ms103.nii.gz --inindex=1 --topup=/Volumes/iang/active/BABIES/BABIES_diffusion/workflows/init_proc_l/applytopup/DTI_topup --method=jac --out=/Volumes/iang/active/BABIES/BABIES_diffusion/subjsDir/Newborn/1042-L-T2/DTI_pe0_corrected.nii.gz
# 180726-18:43:06,560 workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 0 jobs ready. Free memory (GB): 28.60/28.80, Free processors: 0/1.
#                      Currently running:
#                        * init_proc_l.applytopup
# 180726-18:44:45,278 workflow INFO:
# 	 [Node] Finished "init_proc_l.applytopup".
# 180726-18:44:46,637 workflow INFO:
# 	 [Job 0] Completed (init_proc_l.applytopup).
# 180726-18:44:46,640 workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 28.80/28.80, Free processors: 1/1.
# 180726-18:44:46,953 workflow INFO:
# 	 [Node] Outdated cache found for "init_proc_l.bet".
# 180726-18:44:46,955 workflow INFO:
# 	 [Node] Setting-up "init_proc_l.bet" in "/Volumes/iang/active/BABIES/BABIES_diffusion/workflows/init_proc_l/bet".
# 180726-18:44:46,965 workflow INFO:
# 	 [Node] Outdated cache found for "init_proc_l.bet".
# 180726-18:44:47,607 workflow INFO:
# 	 [Node] Running "bet" ("nipype.interfaces.fsl.preprocess.BET"), a CommandLine Interface with command:
# bet /Volumes/iang/active/BABIES/BABIES_diffusion/subjsDir/Newborn/1042-L-T2/DTI_pe0_corrected.nii.gz /Volumes/iang/active/BABIES/BABIES_diffusion/subjsDir/Newborn/1042-L-T2/DTI_pe0_corrected_stripped.nii.gz -m
# 180726-18:44:48,637 workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 0 jobs ready. Free memory (GB): 28.60/28.80, Free processors: 0/1.
#                      Currently running:
#                        * init_proc_l.bet
# 180726-18:44:51,148 workflow INFO:
# 	 [Node] Finished "init_proc_l.bet".
# 180726-18:44:52,637 workflow INFO:
# 	 [Job 1] Completed (init_proc_l.bet).
# 180726-18:44:52,639 workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 0 jobs ready. Free memory (GB): 28.80/28.80, Free processors: 1/1.
# 180726-18:44:55,235 workflow INFO:
# 	 Generated workflow graph: /Volumes/iang/active/BABIES/BABIES_diffusion/workflows/init_proc_l/graph.png (graph2use=flat, simple_form=True).
# 180726-18:44:55,291 workflow INFO:
# 	 Workflow init_proc_l settings: ['check', 'execution', 'logging', 'monitoring']
# 180726-18:44:55,488 workflow INFO:
# 	 Running in parallel.
# 180726-18:44:55,492 workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 28.80/28.80, Free processors: 1/1.
# 180726-18:44:55,593 workflow INFO:
# 	 [Node] Outdated cache found for "init_proc_l.applytopup".
# 180726-18:44:55,599 workflow INFO:
# 	 [Node] Setting-up "init_proc_l.applytopup" in "/Volumes/iang/active/BABIES/BABIES_diffusion/workflows/init_proc_l/applytopup".
# 180726-18:44:55,608 workflow INFO:
# 	 [Node] Outdated cache found for "init_proc_l.applytopup".
# 180726-18:44:56,4 workflow INFO:
# 	 [Node] Running "applytopup" ("nipype.interfaces.fsl.epi.ApplyTOPUP"), a CommandLine Interface with command:
# applytopup --datain=/Volumes/iang/active/BABIES/BABIES_diffusion/subjsDir/acq_params.txt --imain=/Volumes/iang/active/BABIES/BABIES_diffusion/subjsDir/Newborn/1043-L-T2/raw/DTI_pe0_ms103.nii.gz --inindex=1 --topup=/Volumes/iang/active/BABIES/BABIES_diffusion/workflows/init_proc_l/applytopup/DTI_topup --method=jac --out=/Volumes/iang/active/BABIES/BABIES_diffusion/subjsDir/Newborn/1043-L-T2/DTI_pe0_corrected.nii.gz
# 180726-18:44:57,492 workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 0 jobs ready. Free memory (GB): 28.60/28.80, Free processors: 0/1.
#                      Currently running:
#                        * init_proc_l.applytopup
# 180726-18:45:38,555 workflow INFO:
# 	 [Node] Finished "init_proc_l.applytopup".
# 180726-18:45:39,533 workflow INFO:
# 	 [Job 0] Completed (init_proc_l.applytopup).
# 180726-18:45:39,535 workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 28.80/28.80, Free processors: 1/1.
# 180726-18:45:39,925 workflow INFO:
# 	 [Node] Outdated cache found for "init_proc_l.bet".
# 180726-18:45:39,927 workflow INFO:
# 	 [Node] Setting-up "init_proc_l.bet" in "/Volumes/iang/active/BABIES/BABIES_diffusion/workflows/init_proc_l/bet".
# 180726-18:45:39,932 workflow INFO:
# 	 [Node] Outdated cache found for "init_proc_l.bet".
# 180726-18:45:40,101 workflow INFO:
# 	 [Node] Running "bet" ("nipype.interfaces.fsl.preprocess.BET"), a CommandLine Interface with command:
# bet /Volumes/iang/active/BABIES/BABIES_diffusion/subjsDir/Newborn/1043-L-T2/DTI_pe0_corrected.nii.gz /Volumes/iang/active/BABIES/BABIES_diffusion/subjsDir/Newborn/1043-L-T2/DTI_pe0_corrected_stripped.nii.gz -m
# 180726-18:45:41,535 workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 0 jobs ready. Free memory (GB): 28.60/28.80, Free processors: 0/1.
#                      Currently running:
#                        * init_proc_l.bet
# 180726-18:45:42,64 workflow INFO:
# 	 [Node] Finished "init_proc_l.bet".
# 180726-18:45:43,540 workflow INFO:
# 	 [Job 1] Completed (init_proc_l.bet).
# 180726-18:45:43,542 workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 0 jobs ready. Free memory (GB): 28.80/28.80, Free processors: 1/1.
# 180726-18:45:46,227 workflow INFO:
# 	 Generated workflow graph: /Volumes/iang/active/BABIES/BABIES_diffusion/workflows/init_proc_l/graph.png (graph2use=flat, simple_form=True).
# 180726-18:45:46,253 workflow INFO:
# 	 Workflow init_proc_l settings: ['check', 'execution', 'logging', 'monitoring']
# 180726-18:45:46,375 workflow INFO:
# 	 Running in parallel.
# 180726-18:45:46,378 workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 28.80/28.80, Free processors: 1/1.
# 180726-18:45:46,469 workflow INFO:
# 	 [Node] Outdated cache found for "init_proc_l.applytopup".
# 180726-18:45:46,475 workflow INFO:
# 	 [Node] Setting-up "init_proc_l.applytopup" in "/Volumes/iang/active/BABIES/BABIES_diffusion/workflows/init_proc_l/applytopup".
# 180726-18:45:46,485 workflow INFO:
# 	 [Node] Outdated cache found for "init_proc_l.applytopup".
# 180726-18:45:46,707 workflow INFO:
# 	 [Node] Running "applytopup" ("nipype.interfaces.fsl.epi.ApplyTOPUP"), a CommandLine Interface with command:
# applytopup --datain=/Volumes/iang/active/BABIES/BABIES_diffusion/subjsDir/acq_params.txt --imain=/Volumes/iang/active/BABIES/BABIES_diffusion/subjsDir/Newborn/1053-L-T2/raw/DTI_pe0_ms103.nii.gz --inindex=1 --topup=/Volumes/iang/active/BABIES/BABIES_diffusion/workflows/init_proc_l/applytopup/DTI_topup --method=jac --out=/Volumes/iang/active/BABIES/BABIES_diffusion/subjsDir/Newborn/1053-L-T2/DTI_pe0_corrected.nii.gz
# 180726-18:45:48,378 workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 0 jobs ready. Free memory (GB): 28.60/28.80, Free processors: 0/1.
#                      Currently running:
#                        * init_proc_l.applytopup
# 180726-18:46:30,157 workflow INFO:
# 	 [Node] Finished "init_proc_l.applytopup".
# 180726-18:46:30,409 workflow INFO:
# 	 [Job 0] Completed (init_proc_l.applytopup).
# 180726-18:46:30,412 workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 28.80/28.80, Free processors: 1/1.
# 180726-18:46:30,497 workflow INFO:
# 	 [Node] Outdated cache found for "init_proc_l.bet".
# 180726-18:46:30,500 workflow INFO:
# 	 [Node] Setting-up "init_proc_l.bet" in "/Volumes/iang/active/BABIES/BABIES_diffusion/workflows/init_proc_l/bet".
# 180726-18:46:30,507 workflow INFO:
# 	 [Node] Outdated cache found for "init_proc_l.bet".
# 180726-18:46:30,703 workflow INFO:
# 	 [Node] Running "bet" ("nipype.interfaces.fsl.preprocess.BET"), a CommandLine Interface with command:
# bet /Volumes/iang/active/BABIES/BABIES_diffusion/subjsDir/Newborn/1053-L-T2/DTI_pe0_corrected.nii.gz /Volumes/iang/active/BABIES/BABIES_diffusion/subjsDir/Newborn/1053-L-T2/DTI_pe0_corrected_stripped.nii.gz -m
# 180726-18:46:32,367 workflow INFO:
# 	 [Node] Finished "init_proc_l.bet".
# 180726-18:46:32,411 workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 0 jobs ready. Free memory (GB): 28.60/28.80, Free processors: 0/1.
#                      Currently running:
#                        * init_proc_l.bet
# 180726-18:46:34,411 workflow INFO:
# 	 [Job 1] Completed (init_proc_l.bet).
# 180726-18:46:34,413 workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 0 jobs ready. Free memory (GB): 28.80/28.80, Free processors: 1/1.
# 180726-18:46:37,290 workflow INFO:
# 	 Generated workflow graph: /Volumes/iang/active/BABIES/BABIES_diffusion/workflows/init_proc_l/graph.png (graph2use=flat, simple_form=True).
# 180726-18:46:37,316 workflow INFO:
# 	 Workflow init_proc_l settings: ['check', 'execution', 'logging', 'monitoring']
# 180726-18:46:37,489 workflow INFO:
# 	 Running in parallel.
# 180726-18:46:37,493 workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 28.80/28.80, Free processors: 1/1.
# 180726-18:46:37,592 workflow INFO:
# 	 [Node] Outdated cache found for "init_proc_l.applytopup".
# 180726-18:46:37,597 workflow INFO:
# 	 [Node] Setting-up "init_proc_l.applytopup" in "/Volumes/iang/active/BABIES/BABIES_diffusion/workflows/init_proc_l/applytopup".
# 180726-18:46:37,622 workflow INFO:
# 	 [Node] Outdated cache found for "init_proc_l.applytopup".
# 180726-18:46:37,887 workflow INFO:
# 	 [Node] Running "applytopup" ("nipype.interfaces.fsl.epi.ApplyTOPUP"), a CommandLine Interface with command:
# applytopup --datain=/Volumes/iang/active/BABIES/BABIES_diffusion/subjsDir/acq_params.txt --imain=/Volumes/iang/active/BABIES/BABIES_diffusion/subjsDir/Newborn/1057-L-T2/raw/DTI_pe0_ms103.nii.gz --inindex=1 --topup=/Volumes/iang/active/BABIES/BABIES_diffusion/workflows/init_proc_l/applytopup/DTI_topup --method=jac --out=/Volumes/iang/active/BABIES/BABIES_diffusion/subjsDir/Newborn/1057-L-T2/DTI_pe0_corrected.nii.gz
# 180726-18:46:39,494 workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 0 jobs ready. Free memory (GB): 28.60/28.80, Free processors: 0/1.
#                      Currently running:
#                        * init_proc_l.applytopup
# 180726-18:47:17,957 workflow INFO:
# 	 [Node] Finished "init_proc_l.applytopup".
# 180726-18:47:19,512 workflow INFO:
# 	 [Job 0] Completed (init_proc_l.applytopup).
# 180726-18:47:19,514 workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 28.80/28.80, Free processors: 1/1.
# 180726-18:47:19,619 workflow INFO:
# 	 [Node] Outdated cache found for "init_proc_l.bet".
# 180726-18:47:19,621 workflow INFO:
# 	 [Node] Setting-up "init_proc_l.bet" in "/Volumes/iang/active/BABIES/BABIES_diffusion/workflows/init_proc_l/bet".
# 180726-18:47:19,626 workflow INFO:
# 	 [Node] Outdated cache found for "init_proc_l.bet".
# 180726-18:47:19,961 workflow INFO:
# 	 [Node] Running "bet" ("nipype.interfaces.fsl.preprocess.BET"), a CommandLine Interface with command:
# bet /Volumes/iang/active/BABIES/BABIES_diffusion/subjsDir/Newborn/1057-L-T2/DTI_pe0_corrected.nii.gz /Volumes/iang/active/BABIES/BABIES_diffusion/subjsDir/Newborn/1057-L-T2/DTI_pe0_corrected_stripped.nii.gz -m
# 180726-18:47:21,514 workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 0 jobs ready. Free memory (GB): 28.60/28.80, Free processors: 0/1.
#                      Currently running:
#                        * init_proc_l.bet
# 180726-18:47:21,789 workflow INFO:
# 	 [Node] Finished "init_proc_l.bet".
# 180726-18:47:23,515 workflow INFO:
# 	 [Job 1] Completed (init_proc_l.bet).
# 180726-18:47:23,517 workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 0 jobs ready. Free memory (GB): 28.80/28.80, Free processors: 1/1.

# %%
for sub in ready_to_run:
    dest = destfp + '/' + sub + '/'
    pe1_nii = destfp + '/' + sub + '/raw/DTI_pe1.nii.gz'
    pe1_bvec = destfp + '/' + sub + '/raw/DTI_pe1.bvec'
    pe1_bval = destfp + '/' + sub + '/raw/DTI_pe1.bval'
    pe0_nii = destfp + '/' + sub + '/raw/DTI_pe0_ms103.nii.gz'
    pe0_bvec = destfp + '/' + sub + '/raw/DTI_pe0_ms103.bvec'
    pe0_bval = destfp + '/' + sub + '/raw/DTI_pe0_ms103.bval'
    dest = destfp + '/' + sub + '/'
    applytopup = pe.Node(interface = fsl.ApplyTOPUP(encoding_file = params,
                                                    in_files = [pe0_nii],
                                                    method = 'jac',
                                                    in_topup_fieldcoef = dest + 'DTI_topup_fieldcoef.nii.gz',
                                                    in_topup_movpar = dest + 'DTI_topup_movpar.txt',
                                                    in_index = [1],
                                                    out_corrected = dest + 'DTI_pe0_corrected.nii.gz',
                                                    output_type = "NIFTI_GZ"),
                            name = 'applytopup')
    eddy = pe.Node(interface = fsl.Eddy(in_acqp = params, in_bval = pe0_bval, in_bvec = pe0_bvec,
                                            in_index = index104, in_mask = dest + 'DTI_pe0_corrected_stripped_mask.nii.gz',
                                            out_base = dest + 'DTI_unwarped_eddy'),
                                    name = 'eddy')

    eddyflow_l = pe.Workflow(name='eddyflow_l')
    eddyflow_l.connect([(applytopup, eddy, [('out_corrected', 'in_file')])
                     ])
    eddyflow_l.base_dir = workflow_dir
    eddyflow_l.run('MultiProc', plugin_args={'n_procs': 1})
# Out:
# 180726-19:15:05,378 workflow INFO:
# 	 Workflow eddyflow_l settings: ['check', 'execution', 'logging', 'monitoring']
# 180726-19:15:05,465 workflow INFO:
# 	 Running in parallel.
# 180726-19:15:05,469 workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 28.80/28.80, Free processors: 1/1.
# 180726-19:15:05,561 workflow INFO:
# 	 [Job 0] Cached (eddyflow_l.applytopup).
# 180726-19:15:07,592 workflow INFO:
# 	 [Node] Setting-up "eddyflow_l.eddy" in "/Volumes/iang/active/BABIES/BABIES_diffusion/workflows/eddyflow_l/eddy".
# 180726-19:15:07,775 workflow INFO:
# 	 [Node] Running "eddy" ("nipype.interfaces.fsl.epi.Eddy"), a CommandLine Interface with command:
# eddy_openmp --acqp=/Volumes/iang/active/BABIES/BABIES_diffusion/subjsDir/acq_params.txt --bvals=/Volumes/iang/active/BABIES/BABIES_diffusion/subjsDir/Newborn/1005-L-T2/raw/DTI_pe0_ms103.bval --bvecs=/Volumes/iang/active/BABIES/BABIES_diffusion/subjsDir/Newborn/1005-L-T2/raw/DTI_pe0_ms103.bvec --imain=/Volumes/iang/active/BABIES/BABIES_diffusion/subjsDir/Newborn/1005-L-T2/DTI_pe0_corrected.nii.gz --index=/Volumes/iang/active/BABIES/BABIES_diffusion/subjsDir/index105.txt --mask=/Volumes/iang/active/BABIES/BABIES_diffusion/subjsDir/Newborn/1005-L-T2/DTI_pe0_corrected_stripped_mask.nii.gz --out=/Volumes/iang/active/BABIES/BABIES_diffusion/subjsDir/Newborn/1005-L-T2/DTI_unwarped_eddy
# 180726-19:15:09,471 workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 0 jobs ready. Free memory (GB): 28.60/28.80, Free processors: 0/1.
#                      Currently running:
#                        * eddyflow_l.eddy
# 180726-20:23:04,861 workflow INFO:
# 	 [Node] Finished "eddyflow_l.eddy".
# 180726-20:23:05,119 workflow INFO:
# 	 [Job 1] Completed (eddyflow_l.eddy).
# 180726-20:23:05,121 workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 0 jobs ready. Free memory (GB): 28.80/28.80, Free processors: 1/1.
# 180726-20:23:07,235 workflow INFO:
# 	 Workflow eddyflow_l settings: ['check', 'execution', 'logging', 'monitoring']
# 180726-20:23:07,334 workflow INFO:
# 	 Running in parallel.
# 180726-20:23:07,337 workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 28.80/28.80, Free processors: 1/1.
# 180726-20:23:07,439 workflow INFO:
# 	 [Node] Outdated cache found for "eddyflow_l.applytopup".
# 180726-20:23:07,444 workflow INFO:
# 	 [Node] Setting-up "eddyflow_l.applytopup" in "/Volumes/iang/active/BABIES/BABIES_diffusion/workflows/eddyflow_l/applytopup".
# 180726-20:23:07,452 workflow INFO:
# 	 [Node] Outdated cache found for "eddyflow_l.applytopup".
# 180726-20:23:07,775 workflow INFO:
# 	 [Node] Running "applytopup" ("nipype.interfaces.fsl.epi.ApplyTOPUP"), a CommandLine Interface with command:
# applytopup --datain=/Volumes/iang/active/BABIES/BABIES_diffusion/subjsDir/acq_params.txt --imain=/Volumes/iang/active/BABIES/BABIES_diffusion/subjsDir/Newborn/1011-L-T2/raw/DTI_pe0_ms103.nii.gz --inindex=1 --topup=/Volumes/iang/active/BABIES/BABIES_diffusion/workflows/eddyflow_l/applytopup/DTI_topup --method=jac --out=/Volumes/iang/active/BABIES/BABIES_diffusion/subjsDir/Newborn/1011-L-T2/DTI_pe0_corrected.nii.gz
# 180726-20:23:09,337 workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 0 jobs ready. Free memory (GB): 28.60/28.80, Free processors: 0/1.
#                      Currently running:
#                        * eddyflow_l.applytopup
# 180726-20:23:19,906 workflow INFO:
# 	 [Node] Finished "eddyflow_l.applytopup".
# 180726-20:23:21,376 workflow INFO:
# 	 [Job 0] Completed (eddyflow_l.applytopup).
# 180726-20:23:21,378 workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 28.80/28.80, Free processors: 1/1.
# 180726-20:23:21,441 workflow INFO:
# 	 [Node] Outdated cache found for "eddyflow_l.eddy".
# 180726-20:23:21,444 workflow INFO:
# 	 [Node] Setting-up "eddyflow_l.eddy" in "/Volumes/iang/active/BABIES/BABIES_diffusion/workflows/eddyflow_l/eddy".
# 180726-20:23:21,449 workflow INFO:
# 	 [Node] Outdated cache found for "eddyflow_l.eddy".
# 180726-20:23:21,605 workflow INFO:
# 	 [Node] Running "eddy" ("nipype.interfaces.fsl.epi.Eddy"), a CommandLine Interface with command:
# eddy_openmp --acqp=/Volumes/iang/active/BABIES/BABIES_diffusion/subjsDir/acq_params.txt --bvals=/Volumes/iang/active/BABIES/BABIES_diffusion/subjsDir/Newborn/1011-L-T2/raw/DTI_pe0_ms103.bval --bvecs=/Volumes/iang/active/BABIES/BABIES_diffusion/subjsDir/Newborn/1011-L-T2/raw/DTI_pe0_ms103.bvec --imain=/Volumes/iang/active/BABIES/BABIES_diffusion/subjsDir/Newborn/1011-L-T2/DTI_pe0_corrected.nii.gz --index=/Volumes/iang/active/BABIES/BABIES_diffusion/subjsDir/index105.txt --mask=/Volumes/iang/active/BABIES/BABIES_diffusion/subjsDir/Newborn/1011-L-T2/DTI_pe0_corrected_stripped_mask.nii.gz --out=/Volumes/iang/active/BABIES/BABIES_diffusion/subjsDir/Newborn/1011-L-T2/DTI_unwarped_eddy
# 180726-20:23:22,194 workflow WARNING:
# 	 [Node] Error on "eddyflow_l.eddy" (/Volumes/iang/active/BABIES/BABIES_diffusion/workflows/eddyflow_l/eddy)
# 180726-20:23:23,535 workflow ERROR:
# 	 Node eddy failed to run on host myelin.stanford.edu.
# 180726-20:23:23,536 workflow ERROR:
# 	 Saving crash info to /Volumes/iang/active/BABIES/BABIES_diffusion/scripts/crash-20180726-202323-myelin-eddy-9b157a7a-397f-43f9-b33b-02f920f860ec.pklz
# Traceback (most recent call last):
#   File "/usr/local/anaconda3/lib/python3.6/site-packages/nipype/pipeline/plugins/multiproc.py", line 68, in run_node
#     result['result'] = node.run(updatehash=updatehash)
#   File "/usr/local/anaconda3/lib/python3.6/site-packages/nipype/pipeline/engine/nodes.py", line 487, in run
#     result = self._run_interface(execute=True)
#   File "/usr/local/anaconda3/lib/python3.6/site-packages/nipype/pipeline/engine/nodes.py", line 571, in _run_interface
#     return self._run_command(execute)
#   File "/usr/local/anaconda3/lib/python3.6/site-packages/nipype/pipeline/engine/nodes.py", line 650, in _run_command
#     result = self._interface.run(cwd=outdir)
#   File "/usr/local/anaconda3/lib/python3.6/site-packages/nipype/interfaces/base/core.py", line 516, in run
#     runtime = self._run_interface(runtime)
#   File "/usr/local/anaconda3/lib/python3.6/site-packages/nipype/interfaces/fsl/epi.py", line 767, in _run_interface
#     runtime = super(Eddy, self)._run_interface(runtime)
#   File "/usr/local/anaconda3/lib/python3.6/site-packages/nipype/interfaces/base/core.py", line 1023, in _run_interface
#     self.raise_exception(runtime)
#   File "/usr/local/anaconda3/lib/python3.6/site-packages/nipype/interfaces/base/core.py", line 960, in raise_exception
#     ).format(**runtime.dictcopy()))
# RuntimeError: Command:
# eddy --acqp=/Volumes/iang/active/BABIES/BABIES_diffusion/subjsDir/acq_params.txt --bvals=/Volumes/iang/active/BABIES/BABIES_diffusion/subjsDir/Newborn/1011-L-T2/raw/DTI_pe0_ms103.bval --bvecs=/Volumes/iang/active/BABIES/BABIES_diffusion/subjsDir/Newborn/1011-L-T2/raw/DTI_pe0_ms103.bvec --imain=/Volumes/iang/active/BABIES/BABIES_diffusion/subjsDir/Newborn/1011-L-T2/DTI_pe0_corrected.nii.gz --index=/Volumes/iang/active/BABIES/BABIES_diffusion/subjsDir/index105.txt --mask=/Volumes/iang/active/BABIES/BABIES_diffusion/subjsDir/Newborn/1011-L-T2/DTI_pe0_corrected_stripped_mask.nii.gz --out=/Volumes/iang/active/BABIES/BABIES_diffusion/subjsDir/Newborn/1011-L-T2/DTI_unwarped_eddy
# Standard output:
# eddy: msg=--index must be an 1xN or Nx1 matrix where N is the number of volumes in --imain
# eddy: msg=Error when attempting to read --index file
# Standard error:
# libc++abi.dylib: terminating with uncaught exception of type EDDY::EddyException: eddy: msg=Error when attempting to read --index file
# Return code: -6
#
# 180726-20:23:23,545 workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 0 jobs ready. Free memory (GB): 28.80/28.80, Free processors: 1/1.
# 180726-20:23:25,385 workflow INFO:
# 	 ***********************************
# 180726-20:23:25,386 workflow ERROR:
# 	 could not run node: eddyflow_l.eddy
# 180726-20:23:25,386 workflow INFO:
# 	 crashfile: /Volumes/iang/active/BABIES/BABIES_diffusion/scripts/crash-20180726-202323-myelin-eddy-9b157a7a-397f-43f9-b33b-02f920f860ec.pklz
# 180726-20:23:25,387 workflow INFO:
# 	 ***********************************
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-48-b69e21f1a628> in <module>()
#      26                      ])
#      27     eddyflow_l.base_dir = workflow_dir
# ---> 28     eddyflow_l.run('MultiProc', plugin_args={'n_procs': 1})
#      29
#
# /usr/local/anaconda3/lib/python3.6/site-packages/nipype/pipeline/engine/workflows.py in run(self, plugin, plugin_args, updatehash)
#     600         if str2bool(self.config['execution']['create_report']):
#     601             self._write_report_info(self.base_dir, self.name, execgraph)
# --> 602         runner.run(execgraph, updatehash=updatehash, config=self.config)
#     603         datestr = datetime.utcnow().strftime('%Y%m%dT%H%M%S')
#     604         if str2bool(self.config['execution']['write_provenance']):
#
# /usr/local/anaconda3/lib/python3.6/site-packages/nipype/pipeline/plugins/base.py in run(self, graph, config, updatehash)
#     196
#     197         self._remove_node_dirs()
# --> 198         report_nodes_not_run(notrun)
#     199
#     200         # close any open resources
#
# /usr/local/anaconda3/lib/python3.6/site-packages/nipype/pipeline/plugins/tools.py in report_nodes_not_run(notrun)
#      76                 logger.debug(subnode._id)
#      77         logger.info("***********************************")
# ---> 78         raise RuntimeError(('Workflow did not execute cleanly. '
#      79                             'Check log for details'))
#      80
#
# RuntimeError: Workflow did not execute cleanly. Check log for details
